# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Prophet-라이브러리-사용" data-toc-modified-id="Prophet-라이브러리-사용-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Prophet 라이브러리 사용</a></span></li><li><span><a href="#ARIMA-사용" data-toc-modified-id="ARIMA-사용-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>ARIMA 사용</a></span><ul class="toc-item"><li><span><a href="#정상성(Stationary)-체크하기" data-toc-modified-id="정상성(Stationary)-체크하기-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>정상성(Stationary) 체크하기</a></span></li><li><span><a href="#Auto-ARIMA-사용해-학습-및-예측" data-toc-modified-id="Auto-ARIMA-사용해-학습-및-예측-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Auto ARIMA 사용해 학습 및 예측</a></span></li></ul></li><li><span><a href="#머신러닝" data-toc-modified-id="머신러닝-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>머신러닝</a></span><ul class="toc-item"><li><span><a href="#1년치-교차검증-수행하는-함수-만들기(고전적-교차검증-방법)" data-toc-modified-id="1년치-교차검증-수행하는-함수-만들기(고전적-교차검증-방법)-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>1년치 교차검증 수행하는 함수 만들기(고전적 교차검증 방법)</a></span></li><li><span><a href="#Linear-Regression" data-toc-modified-id="Linear-Regression-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Linear Regression</a></span></li><li><span><a href="#Polynomial-Linear-Regression" data-toc-modified-id="Polynomial-Linear-Regression-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Polynomial Linear Regression</a></span></li><li><span><a href="#Random-Forest-Regressor" data-toc-modified-id="Random-Forest-Regressor-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Random Forest Regressor</a></span></li><li><span><a href="#XGBoost-Regressor" data-toc-modified-id="XGBoost-Regressor-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>XGBoost Regressor</a></span></li><li><span><a href="#LightGBM" data-toc-modified-id="LightGBM-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>LightGBM</a></span></li><li><span><a href="#MLP-Regressor" data-toc-modified-id="MLP-Regressor-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>MLP Regressor</a></span></li></ul></li><li><span><a href="#PLS-Regression" data-toc-modified-id="PLS-Regression-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>PLS Regression</a></span><ul class="toc-item"><li><span><a href="#Hybrid-Voting" data-toc-modified-id="Hybrid-Voting-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Hybrid Voting</a></span></li><li><span><a href="#PCA-수행-후-LightGBM" data-toc-modified-id="PCA-수행-후-LightGBM-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>PCA 수행 후 LightGBM</a></span></li><li><span><a href="#Deep-Learning---LSTM" data-toc-modified-id="Deep-Learning---LSTM-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Deep Learning - LSTM</a></span></li></ul></li><li><span><a href="#2009년~2013년-추가된-데이터로-재-모델링" data-toc-modified-id="2009년~2013년-추가된-데이터로-재-모델링-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>2009년~2013년 추가된 데이터로 재 모델링</a></span><ul class="toc-item"><li><span><a href="#추가된-데이터-모으고-전처리-하는-코드" data-toc-modified-id="추가된-데이터-모으고-전처리-하는-코드-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>추가된 데이터 모으고 전처리 하는 코드</a></span></li><li><span><a href="#2020년-1년치-1개의-데이터씩-교차검증하는-함수" data-toc-modified-id="2020년-1년치-1개의-데이터씩-교차검증하는-함수-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>2020년 1년치 1개의 데이터씩 교차검증하는 함수</a></span></li><li><span><a href="#Random-Forest-Regressor" data-toc-modified-id="Random-Forest-Regressor-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Random Forest Regressor</a></span></li><li><span><a href="#Hybrid-Voting-Regressor" data-toc-modified-id="Hybrid-Voting-Regressor-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Hybrid Voting Regressor</a></span></li><li><span><a href="#Hyperparameter-Tuning" data-toc-modified-id="Hyperparameter-Tuning-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Hyperparameter Tuning</a></span></li></ul></li><li><span><a href="#최종-모델-RandomForest-Regressor로-2020년-매출-예측" data-toc-modified-id="최종-모델-RandomForest-Regressor로-2020년-매출-예측-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>최종 모델 RandomForest Regressor로 2020년 매출 예측</a></span><ul class="toc-item"><li><span><a href="#최종-모델-잔차-검정" data-toc-modified-id="최종-모델-잔차-검정-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>최종 모델 잔차 검정</a></span><ul class="toc-item"><li><span><a href="#잔차-정규성" data-toc-modified-id="잔차-정규성-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>잔차 정규성</a></span></li><li><span><a href="#잔차-선형성,-독립성,-등분산성" data-toc-modified-id="잔차-선형성,-독립성,-등분산성-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>잔차 선형성, 독립성, 등분산성</a></span></li><li><span><a href="#잔차-자기상관성" data-toc-modified-id="잔차-자기상관성-6.1.3"><span class="toc-item-num">6.1.3&nbsp;&nbsp;</span>잔차 자기상관성</a></span></li></ul></li></ul></li><li><span><a href="#Feature-Importance" data-toc-modified-id="Feature-Importance-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Feature Importance</a></span><ul class="toc-item"><li><span><a href="#Permutation-Importance" data-toc-modified-id="Permutation-Importance-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Permutation Importance</a></span></li><li><span><a href="#Feature-Importance-of-Random-Forest" data-toc-modified-id="Feature-Importance-of-Random-Forest-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Feature Importance of Random Forest</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings(action='ignore')
os.chdir('/Users/younghun/Desktop/gitrepo/data/woochuri/')

df = pd.read_csv('./woochuri_final_data.csv')

print(df.shape)
df.head() # 한우 < 육우가격 이상치 데이터(2020-10-07일 1개)제외한 상태
# Out:
# (2915, 18)
#            날짜         요일      일매출  설_추석_가중치  일반공휴일가중치     한우가격    육우가격  \
# 0  2013-01-07     Monday   422400         0         0  14548.0  9169.0
# 1  2013-01-08    Tuesday   461900         0         0  15082.0  8105.0
# 2  2013-01-09  Wednesday   492500         0         0  15030.0  9669.0
# 3  2013-01-10   Thursday   701300         0         0  15229.0  9674.0
# 4  2013-01-11     Friday  1035000         0         0  14920.0  8286.0
#
#    돼지탕박가격  평균상대습도  최소상대습도  평균기온  최고기온  최저기온  평균풍속  최대풍속    일사량  1시간최다일사량  일강수량
# 0  3140.0    66.4    32.0  -5.0   1.0 -10.7   1.0   2.7  10.99      2.06   0.0
# 1  3024.0    68.0    43.0  -4.2   1.9  -9.2   1.1   3.0  11.16      1.87   0.0
# 2  3096.0    59.5    39.0  -6.3  -1.9  -9.7   1.9   5.2  12.34      2.13   0.0
# 3  3000.0    54.9    29.0  -7.9  -1.5 -13.8   1.1   3.1  12.69      2.15   0.0
# 4  2963.0    70.0    50.0  -5.3   1.9 -12.8   0.9   1.9  11.05      1.99   0.0

# %% [markdown]
# ## Prophet 라이브러리 사용
#
# - 결측치 제거할 필요 X
# - 독립변수 추가로 가능하지만 추가 시 미래의 Y값을 예측하기 위해 직전의 Y값을 사용하지 않고 추가된 독립변수만을 사용

# %%
from fbprophet import Prophet
fb_df = df[['날짜', '일매출']]

fb_df['일매출'] = fb_df['일매출'].replace(0, np.nan)
fb_df.isnull().sum()
# Out:
# 날짜      0
# 일매출    86
# dtype: int64

# %%
# 간단하게 시각화해보기
from matplotlib import pyplot
fb_df.plot()
pyplot.rc('font', family='AppleGothic')
pyplot.rcParams['axes.unicode_minus'] = False
pyplot.show()

# %%
TRAIN_SPLIT = len(fb_df) - (365+1)
for i in range(0, len(fb_df)-1-TRAIN_SPLIT):
    print(TRAIN_SPLIT+i, TRAIN_SPLIT+i+1)

# %%
from sklearn.metrics import mean_absolute_error
import time

# 365일 1년치 교차검증 시키기
fb_df.columns = ['ds', 'y']
fb_df['ds'] = pd.to_datetime(fb_df['ds'])
TRAIN_SPLIT = len(fb_df) - (365+1)
index_lst = []
pred_lst = []

start_time = time.time()
for i in range(0, (len(fb_df)-(1+TRAIN_SPLIT))):
    if i % 100 == 0:
        print(f"{i}번째 교차 검증 시작")
    train = fb_df.iloc[:TRAIN_SPLIT+i]
    test = fb_df.iloc[TRAIN_SPLIT+i+1]
    test = pd.DataFrame(test.values.reshape(1, -1),
                       columns=train.columns)
    
    model = Prophet()
    model.fit(train)
    
    forecast = model.predict(test[['ds']]) # dataframe 형태로!
    y_pred = forecast['yhat'].values[0]
    pred_lst.append(y_pred)
    index_lst.append(TRAIN_SPLIT+i+1)
    
end_time = time.time() - start_time
print("교차검증 수행시간:", end_time)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 0번째 교차 검증 시작
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 100번째 교차 검증 시작
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 200번째 교차 검증 시작
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 300번째 교차 검증 시작
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 교차검증 수행시간: 532.0279860496521

# %%
# 성능 측정은 y값이 NaN값이 아닌 데이터들로만 측정
test_df = fb_df.iloc[index_lst]
test_df = test_df.reset_index(drop=True)
not_nan_idx = test_df[~test_df['y'].isnull()].index
test_df = test_df[~test_df['y'].isnull()]
test_df['y_pred'] = pd.Series(pred_lst)[not_nan_idx]

test_df['score'] = 0
test_df.loc[abs(test_df['y']-test_df['y_pred']) < 1e5, 'score'] = 1

test_mae = mean_absolute_error(test_df['y'], test_df['y_pred'])
test_acc = test_df['score'].mean() * 100
print(f"# Test MAE: {int(test_mae/1e4): .0f}만원")
print(f"# Test Accuracy: {test_acc: .2f}")

test_df = test_df.set_index('ds')
# Out:
# # Test MAE:  40만원
# # Test Accuracy:  37.29

# %%
pyplot.figure(figsize=(12, 7))
pyplot.plot(test_df['y'], label='Label')
pyplot.plot(test_df['y_pred'], label='Predicted')
pyplot.title("Prophet 라이브러리로 예측한 2020년 1년 교차검증 후 그래프",
            fontsize=17)
pyplot.xlabel("날짜", fontsize=15)
pyplot.ylabel("MAE Error", fontsize=15)
pyplot.legend()
pyplot.show()

# %% [markdown]
# ## ARIMA 사용
#
# - 우선 일매출값의 정상성 확보
# - 결측치 없애야 함 => 일매출값이 0인 값들 제외
# - AR, MA 차수 범위 확인 후 Auto Arima 적용

# %% [markdown]
# ### 정상성(Stationary) 체크하기

# %%
# 우선 휴무라서 매출이 0인 데이터는 제외하고 정상성 체크해보기
# 일매출이 0인 값들 제외
print("제거하기 전 shape:", df.shape)
non_zero = df[df['일매출'] != 0]

print("제거한 후 shape:", non_zero.shape)
# Out:
# 제거하기 전 shape: (2915, 18)
# 제거한 후 shape: (2829, 18)

# %%
# ACF, PACF 그래프 그려보기
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

fig, axes = plt.subplots(figsize=(10, 10), nrows=2, ncols=1, squeeze=True)
plot_acf(non_zero['일매출'], ax=axes[0])
plot_pacf(non_zero['일매출'], ax=axes[1])
plt.show()

# %% [markdown]
# - ``일반 AR,MA 차수 체크``
#     - ACF 함수 그래프에서 파란색 부분을 튀어나온 개수만큼 MA 수행
#         - 0번 ~ 3번 또는 4번
#     - PACF 함수 그래프에서 파란색 부분을 튀어나온 개수만큼 AR 수행
#         - 0번 ~ 3번 또는 4번

# %% [markdown]
# - ``계절성 AR,MA 차수 체크``(lag=4의 배수일 때의 막대를 확인!)
#     - ACF 함수 그래프에서 lag=4일 때 튀어나온 막대 개수만큼 MA 수행
#         - 0번 ~ 1번
#     - PACF 함수 그래프에서 lag=4일 때 튀어나온 막대 개수만큼 AR 수행
#         - 0번 ~ 1번

# %%
# 해당 시계열 데이터의 정상성 통계적 검정하기
# 1. KPSS 검정 - 귀무가설 : 해당 시계열 데이터는 정상성이다.
from statsmodels.tsa.stattools import kpss
stats, p_value, n_lags, c_values = kpss(non_zero['일매출'])

print("KPSS 검정통계량:", stats)
print("P-value:", p_value)

if p_value < 0.05:
    print("귀무가설을 기각! 즉, 해당 데이터는 비정상성이다!")
else:
    print("귀무가설을 채택! 즉, 해당 데이터는 정상성이다!")
# Out:
# KPSS 검정통계량: 0.1493985081951096
# P-value: 0.1
# 귀무가설을 채택! 즉, 해당 데이터는 정상성이다!
# /Users/younghun/opt/anaconda3/envs/venvforpython/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:1886: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warn_msg.format(direction="greater"), InterpolationWarning

# %%
# ADFuller Test도 수행 - 귀무가설 : 해당 시계열 데이터는 비정상성이다.
from statsmodels.tsa.stattools import adfuller

res = adfuller(non_zero['일매출'])
print("ADFuller 검정통계량:", res[0])
print("P-value:", res[1])

if res[1] < 0.05:
    print("귀무가설을 기각! 즉, 해당 데이터는 정상성이다!")
else:
    print("귀무가설을 채택! 즉, 해당 데이터는 비정상성이다!")
# Out:
# ADFuller 검정통계량: -16.731526931101694
# P-value: 1.3818258984652357e-29
# 귀무가설을 기각! 즉, 해당 데이터는 정상성이다!

# %% [markdown]
# ### Auto ARIMA 사용해 학습 및 예측
#
# - 우선 1년치 365일 데이터를 하나의 검증 데이터로 사용해서 한 번에 365일치 데이터를 예측해서 최적의 ARIMA 모델을 찾기(시간 복잡도 감안..)
# - 그리고 최적의 ARIMA 모델을 이용해서 365일 하루씩 고전적인 방법으로 교차 검증 시도(365일 1년치)

# %%
from pmdarima.arima import auto_arima

non_zero['날짜'] = pd.to_datetime(non_zero['날짜'])
non_zero = non_zero.set_index('날짜')

# %%
# Split train, test
splits = non_zero.shape[0] - 365

train = non_zero[['일매출']][:splits]
test = non_zero[['일매출']][splits:]

# p = AR, q = MA, d = 차분
# 대문자 P,D,Q 파라미터는 계절적 요소알아보는 것!
# m = 계절 차분에 대한 periods 설정인데, daily=7로 설정!
arima_model = auto_arima(train, start_p=0, d=0, start_q=0,
                        max_p=4, max_d=1, max_q=4,
                        start_P=0, D=0, start_Q=0,
                        max_P=1, max_D=5, max_Q=1,
                        m=7, seasonal=True,
                        error_action='warn', trace=True,
                        stepwise=True, random_state=42)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[7] intercept   : AIC=75847.826, Time=0.10 sec
#  ARIMA(1,0,0)(1,0,0)[7] intercept   : AIC=73972.101, Time=0.37 sec
#  ARIMA(0,0,1)(0,0,1)[7] intercept   : AIC=74134.573, Time=0.45 sec
#  ARIMA(0,0,0)(0,0,0)[7]             : AIC=76653.545, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[7] intercept   : AIC=73970.900, Time=0.10 sec
#  ARIMA(1,0,0)(0,0,1)[7] intercept   : AIC=73972.106, Time=0.29 sec
#  ARIMA(1,0,0)(1,0,1)[7] intercept   : AIC=73974.095, Time=0.59 sec
#  ARIMA(2,0,0)(0,0,0)[7] intercept   : AIC=73686.105, Time=0.16 sec
#  ARIMA(2,0,0)(1,0,0)[7] intercept   : AIC=73685.715, Time=0.44 sec
#  ARIMA(2,0,0)(1,0,1)[7] intercept   : AIC=73687.611, Time=0.70 sec
#  ARIMA(2,0,0)(0,0,1)[7] intercept   : AIC=73685.627, Time=0.31 sec
#  ARIMA(3,0,0)(0,0,1)[7] intercept   : AIC=73613.159, Time=0.41 sec
#  ARIMA(3,0,0)(0,0,0)[7] intercept   : AIC=73611.902, Time=0.22 sec
#  ARIMA(3,0,0)(1,0,0)[7] intercept   : AIC=73613.154, Time=0.67 sec
#  ARIMA(3,0,0)(1,0,1)[7] intercept   : AIC=73615.146, Time=0.93 sec
#  ARIMA(4,0,0)(0,0,0)[7] intercept   : AIC=73586.214, Time=0.28 sec
#  ARIMA(4,0,0)(1,0,0)[7] intercept   : AIC=73585.279, Time=0.67 sec
#  ARIMA(4,0,0)(1,0,1)[7] intercept   : AIC=73587.249, Time=1.23 sec
#  ARIMA(4,0,0)(0,0,1)[7] intercept   : AIC=73585.324, Time=0.51 sec
#  ARIMA(4,0,1)(1,0,0)[7] intercept   : AIC=73584.244, Time=1.44 sec
#  ARIMA(4,0,1)(0,0,0)[7] intercept   : AIC=73585.950, Time=1.03 sec
#  ARIMA(4,0,1)(1,0,1)[7] intercept   : AIC=73574.748, Time=1.65 sec
#  ARIMA(4,0,1)(0,0,1)[7] intercept   : AIC=73585.669, Time=1.20 sec
#  ARIMA(3,0,1)(1,0,1)[7] intercept   : AIC=73573.037, Time=1.21 sec
#  ARIMA(3,0,1)(0,0,1)[7] intercept   : AIC=73593.800, Time=0.86 sec
#  ARIMA(3,0,1)(1,0,0)[7] intercept   : AIC=73591.352, Time=0.98 sec
#  ARIMA(3,0,1)(0,0,0)[7] intercept   : AIC=73593.738, Time=0.67 sec
#  ARIMA(2,0,1)(1,0,1)[7] intercept   : AIC=73571.396, Time=0.95 sec
#  ARIMA(2,0,1)(0,0,1)[7] intercept   : AIC=73595.222, Time=0.62 sec
#  ARIMA(2,0,1)(1,0,0)[7] intercept   : AIC=73592.087, Time=0.75 sec
#  ARIMA(2,0,1)(0,0,0)[7] intercept   : AIC=73595.579, Time=0.34 sec
#  ARIMA(1,0,1)(1,0,1)[7] intercept   : AIC=73570.368, Time=0.71 sec
#  ARIMA(1,0,1)(0,0,1)[7] intercept   : AIC=73589.566, Time=0.45 sec
#  ARIMA(1,0,1)(1,0,0)[7] intercept   : AIC=73586.466, Time=0.47 sec
#  ARIMA(1,0,1)(0,0,0)[7] intercept   : AIC=73590.017, Time=0.22 sec
#  ARIMA(0,0,1)(1,0,1)[7] intercept   : AIC=74111.521, Time=0.58 sec
#  ARIMA(1,0,2)(1,0,1)[7] intercept   : AIC=73571.228, Time=1.07 sec
#  ARIMA(0,0,0)(1,0,1)[7] intercept   : AIC=75851.348, Time=0.40 sec
#  ARIMA(0,0,2)(1,0,1)[7] intercept   : AIC=73731.047, Time=0.69 sec
#  ARIMA(2,0,2)(1,0,1)[7] intercept   : AIC=73572.457, Time=2.72 sec
#  ARIMA(1,0,1)(1,0,1)[7]             : AIC=inf, Time=1.87 sec
#
# Best model:  ARIMA(1,0,1)(1,0,1)[7] intercept
# Total fit time: 29.340 seconds

# %%
arima_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                                 y   No. Observations:                 2464
# Model:             SARIMAX(1, 0, 1)x(1, 0, 1, 7)   Log Likelihood              -36779.184
# Date:                           Sun, 21 Mar 2021   AIC                          73570.368
# Time:                                   14:34:00   BIC                          73605.225
# Sample:                                        0   HQIC                         73583.032
#                                           - 2464
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   2.315e+05   4.57e-07   5.06e+11      0.000    2.31e+05    2.31e+05
# ar.L1          0.5085      0.007     71.803      0.000       0.495       0.522
# ma.L1          0.5558      0.006     88.760      0.000       0.543       0.568
# ar.S.L7        0.3548      0.080      4.440      0.000       0.198       0.511
# ma.S.L7       -0.3252      0.088     -3.708      0.000      -0.497      -0.153
# sigma2       5.52e+11    1.8e-12   3.07e+23      0.000    5.52e+11    5.52e+11
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):            329028.90
# Prob(Q):                              0.84   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.29   Skew:                             4.71
# Prob(H) (two-sided):                  0.00   Kurtosis:                        58.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.84e+37. Standard errors may be unstable.
# """

# %%
test['y_pred'] = arima_model.predict(n_periods=test.shape[0])
test['score'] = 0
test.loc[abs(test['일매출']-test['y_pred']) < 1e5, 'score'] = 1

test_mae = mean_absolute_error(test['일매출'], test['y_pred'])
test_acc = test['score'].mean() * 100

print(f"# Test MAE: {test_mae/1e4 : .0f}만원")
print(f"# Test Accuracy: {test_acc :.2f}%")
# Out:
# # Test MAE:  43만원
# # Test Accuracy: 11.51%

# %%
# 위에서 찾은 최적의 SARIMA 모델로 교차검증 수행
from pmdarima.arima import ARIMA

# 365일 1년치 교차검증 시키기
cross_df = non_zero[['일매출']]
TRAIN_SPLIT = len(cross_df) - (365+1)
index_lst = []
pred_lst = []

start_time = time.time()
for i in range(0, (len(non_zero)-(1+TRAIN_SPLIT))):
    if i % 100 == 0:
        print('#', i, "번째 교차검증 수행")
    start_time = time.time()

    train = cross_df.iloc[:TRAIN_SPLIT+i]
    test = cross_df.iloc[TRAIN_SPLIT+i+1]
    test = pd.DataFrame(test.values.reshape(1, -1),
                       columns=train.columns)
    
    model = ARIMA(order=(1, 0, 1),
                 seasonal_order=(1, 0, 1, 7))
    model.fit(train.values)
    
    forecast = model.predict(n_periods=1)
    y_pred = forecast[0]
    pred_lst.append(y_pred)
    index_lst.append(TRAIN_SPLIT+i+1)
    
end_time = time.time() - start_time
print("교차검증 수행시간:", end_time)
# Out:
# # 0 번째 교차검증 수행
# # 100 번째 교차검증 수행
# # 200 번째 교차검증 수행
# # 300 번째 교차검증 수행
# 교차검증 수행시간: 0.8243520259857178

# %%
test_idx = non_zero[len(non_zero)-365:].index
test_df = pd.DataFrame(data=non_zero[len(non_zero)-365:]['일매출'],
                      index=test_idx)
test_df['y_pred'] = np.array(pred_lst)

test_df['score'] = 0
test_df.loc[abs(test_df['일매출']-test_df['y_pred']) < 1e5, 'score'] = 1

test_mae = mean_absolute_error(test_df['일매출'], test_df['y_pred'])
test_acc = test_df['score'].mean() * 100

print(f"# Test MAE: {test_mae/1e4: .0f}만원")
print(f"# Test Accuracy: {test_acc: .2f}%")
# Out:
# # Test MAE:  40만원
# # Test Accuracy:  23.29%

# %% [markdown]
# ## 머신러닝

# %% [markdown]
# ### 1년치 교차검증 수행하는 함수 만들기(고전적 교차검증 방법)

# %% [markdown]
# - 헷갈리니 다시 데이터 로드

# %%
import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings(action='ignore')
os.chdir('/Users/younghun/Desktop/gitrepo/data/woochuri/')

df = pd.read_csv('./woochuri_final_data.csv')
df.shape
# Out:
# (2916, 18)

# %%
# 다중공선성 변수 제거
multi_cols = ['최소상대습도', '최저기온', '평균기온', '1시간최다일사량']
dataset = df.drop(multi_cols, axis=1)
# 날짜 인덱스로 옮기기
dataset['날짜'] = pd.to_datetime(dataset['날짜'])
dataset = dataset.set_index('날짜')

# %%
# 우선 매출이 0인 값들 요일 평균값으로 대체
non_zero_sales = dataset[dataset['일매출'] != 0]
days = non_zero_sales.groupby('요일')['일매출'].mean().index
means = non_zero_sales.groupby('요일')['일매출'].mean().values
weekdays_means = dict(zip(days, means))

def replace_zero_sales(df):
    if df['일매출'] == 0:
        df['일매출'] = weekdays_means[df['요일']]
    return df

dataset = dataset.apply(replace_zero_sales, axis=1)

# 요일변수 요일별 매출 평균값 가중치로 변경
total = dataset.groupby('요일')['일매출'].mean().values.sum()
weekdays = dataset.groupby('요일')['일매출'].mean().index
values = np.round(dataset.groupby('요일')['일매출'].mean().values / total * 100, 2)
weekdays_dict = dict(zip(weekdays, values))

dataset['요일'] = dataset['요일'].map(weekdays_dict)

# %%
#### 1년치 교차검증 함수 만들기 ####
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
import time
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# dataframe에는 전처리된 데이터프레임 넣어야 함!
def evaluate_cv_predict(dataframe, regressor):
    start_time = time.time()

    # 교차검증 1번 수행할 때마다 예측값 담을 리스트
    train_mae_lst = []  # 학습 데이터에 대한 MAE 담기 for overfitting 여부 확인
    test_pred_lst = []  # 비교하기 위해 1개의 미래 데이터에 대한 예측값 담기
    test_y_lst = []     # 비교하기 위해 1개의 미래 데이터에 대한 실제값 담기


    TRAIN_SPLIT = len(dataset) - 365
    for i in range(0, len(dataset)-(TRAIN_SPLIT)):
        if i % 10 == 0 and i > 0:
            print(f"## {i}번째 교차검증 수행")
        dataset['target'] = np.append(np.array(dataset['일매출'][1:]), 0)
        train = dataset.iloc[:i+TRAIN_SPLIT-1] # dataframe
        test = dataset.iloc[i+TRAIN_SPLIT-1] # Series
        test_y_lst.append(test[-1]) # Target값 저장
        test = pd.DataFrame(data=test.values.reshape(1, -1),
                           columns=test.index) # Convert Series to Dataframe
        X_train, y_train = train.iloc[:, :-1], train.iloc[:, -1]
        X_test, y_test = test.iloc[:, :-1], test.iloc[:, -1]

        # Scaling
        scaler = MinMaxScaler()
        no_scale_cols = ['요일', '설_추석_가중치', '일반공휴일가중치']
        scale_cols = ['일매출', '한우가격', '육우가격', '돼지탕박가격', '평균상대습도', '최고기온', '평균풍속', '최대풍속',
                      '일사량', '일강수량']

        X_train_scale = X_train[scale_cols]
        X_train_no_scale = X_train[no_scale_cols]
        X_test_scale = X_test[scale_cols]
        X_test_no_scale = X_test[no_scale_cols]

        X_train_scale = pd.DataFrame(scaler.fit_transform(X_train_scale),
                                     columns=X_train_scale.columns,
                                     index=X_train_scale.index)
        X_test_scale = pd.DataFrame(scaler.transform(X_test_scale),
                                    columns=X_test_scale.columns,
                                    index=X_test_scale.index)

        X_train = pd.concat([X_train_scale, X_train_no_scale], axis=1)
        X_test = pd.concat([X_test_scale, X_test_no_scale], axis=1)

        # fitting
        model = regressor
        model.fit(X_train, y_train)
        # predict
        train_pred = model.predict(X_train)
        test_pred = model.predict(X_test)
        # Evaluate
        train_mae = mean_absolute_error(y_train, train_pred)
        train_mae_lst.append(train_mae)
        test_pred_lst.append(test_pred[0])
    end_time = time.time() - start_time
    
    # 364번 각 교차검증할 때마다 담은 Train 데이터에 대한 MAE값들의 평균 값
    TRAIN_MAE = np.array(train_mae_lst).mean()
    TEST_DF = pd.DataFrame()
    TEST_DF['y_true'] = np.array(test_y_lst)
    TEST_DF['y_pred'] = np.array(test_pred_lst)

    TEST_DF['score'] = 0
    TEST_DF.loc[abs(TEST_DF['y_true']-TEST_DF['y_pred']) < 1e5, 'score'] = 1
    TEST_DF = TEST_DF.set_index(dataset.iloc[len(dataset)-365:].index)
    TEST_MAE = mean_absolute_error(TEST_DF['y_true'], TEST_DF['y_pred'])
    TEST_ACC = TEST_DF['score'].mean() * 100

    print("## 365번 교차검증 수행 시간:", end_time)
    print()
    print(f"## 365번 교차검증에 대한 Train 데이터 MAE:{TRAIN_MAE/1e4: .0f}만원")
    print()
    print(f"## 365번 교차검증에 대한 Test 데이터 MAE:{TEST_MAE/1e4: .0f}만원")
    print()
    print(f"## 365번 교차검증 후 365번의 예측에 대해서 오차 10만원 미만으로 예측한 데이터 비율:{TEST_ACC: .2f}%")

    # Graph label and prediction
    plt.figure(figsize=(12, 7))
    sns.lineplot(data=TEST_DF[['y_true', 'y_pred']])
    plt.title("실제값과 예측값 Line Graph", fontsize=20)
    plt.xlabel("날짜", fontsize=17)
    plt.ylabel("MAE Error", fontsize=17)
    plt.legend(['Label', 'Predicted'])
    plt.show()
    
    return TEST_DF, TRAIN_MAE

# %%
# 1년치 교차검증 함수 만들기
# from sklearn.preprocessing import MinMaxScaler
# from sklearn.ensemble import RandomForestRegressor
# import time

# start_time = time.time()

# # 교차검증 1번 수행할 때마다 예측값 담을 리스트
# train_mae_lst = []  # 학습 데이터에 대한 MAE 담기 for overfitting 여부 확인
# test_pred_lst = []  # 비교하기 위해 1개의 미래 데이터에 대한 예측값 담기
# test_y_lst = []     # 비교하기 위해 1개의 미래 데이터에 대한 실제값 담기


# TRAIN_SPLIT = len(dataset) - 365
# for i in range(0, len(dataset)-(TRAIN_SPLIT)):
#     if i+1 % 10 == 0:
#         print(f"## {i+1}번째 교차검증 수행")
#     dataset['target'] = np.append(np.array(dataset['일매출'][1:]), 0)
#     train = dataset.iloc[:i+TRAIN_SPLIT-1] # dataframe
#     test = dataset.iloc[i+TRAIN_SPLIT-1] # Series
#     test_y_lst.append(test[-1]) # Target값 저장
#     test = pd.DataFrame(data=test.values.reshape(1, -1),
#                        columns=test.index) # Convert Series to Dataframe
#     X_train, y_train = train.iloc[:, :-1], train.iloc[:, -1]
#     X_test, y_test = test.iloc[:, :-1], test.iloc[:, -1]

#     # Scaling
#     scaler = MinMaxScaler()
#     no_scale_cols = ['요일', '설_추석_가중치', '일반공휴일가중치']
#     scale_cols = ['일매출', '한우가격', '육우가격', '돼지탕박가격', '평균상대습도', '최고기온', '평균풍속', '최대풍속',
#                   '일사량', '일강수량']
    
#     X_train_scale = X_train[scale_cols]
#     X_train_no_scale = X_train[no_scale_cols]
#     X_test_scale = X_test[scale_cols]
#     X_test_no_scale = X_test[no_scale_cols]

#     X_train_scale = pd.DataFrame(scaler.fit_transform(X_train_scale),
#                                  columns=X_train_scale.columns,
#                                  index=X_train_scale.index)
#     X_test_scale = pd.DataFrame(scaler.transform(X_test_scale),
#                                 columns=X_test_scale.columns,
#                                 index=X_test_scale.index)

#     X_train = pd.concat([X_train_scale, X_train_no_scale], axis=1)
#     X_test = pd.concat([X_test_scale, X_test_no_scale], axis=1)
    
#     # fitting
#     model = RandomForestRegressor()
#     model.fit(X_train, y_train)
#     # predict
#     train_pred = model.predict(X_train)
#     test_pred = model.predict(X_test)
#     # Evaluate
#     train_mae = mean_absolute_error(y_train, train_pred)
#     train_mae_lst.append(train_mae)
#     test_pred_lst.append(test_pred[0])
    
# # 364번 각 교차검증할 때마다 담은 Train 데이터에 대한 MAE값들의 평균 값
# TRAIN_MAE = np.array(train_mae_lst).mean()
# TEST_DF = pd.DataFrame()
# TEST_DF['y_true'] = np.array(test_y_lst)
# TEST_DF['y_pred'] = np.array(test_pred_lst)

# TEST_DF['score'] = 0
# TEST_DF.loc[abs(TEST_DF['y_true']-TEST_DF['y_pred']) < 1e5, 'score'] = 1
# TEST_DF = TEST_DF.set_index(dataset.iloc[len(dataset)-365:].index)
# TEST_MAE = mean_absolute_error(TEST_DF['y_true'], TEST_DF['y_pred'])
# TEST_ACC = TEST_DF['score'].mean() * 100

# print(f"## 365번 교차검증에 대한 Train 데이터 MAE:{TRAIN_MAE/1e4: .0f}만원")
# print()
# print(f"## 365번 교차검증에 대한 Test 데이터 MAE:{TEST_MAE/1e4: .0f}만원")
# print()
# print(f"## 365번 교차검증 후 365번의 예측에 대해서 오차 10만원 미만으로 예측한 데이터 비율:{TEST_ACC: .2f}%")

# # Graph label and prediction
# plt.figure(figsize=(12, 7))
# sns.lineplot(data=TEST_DF[['y_true', 'y_pred']])
# plt.title("실제값과 예측값 Line Graph", fontsize=20)
# plt.xlabel("날짜", fontsize=17)
# plt.ylabel("MAE Error", fontsize=17)
# plt.legend(['Label', 'Predicted'])
# plt.show()
# Out:
# ## 0번째 교차검증 수행
# ## 10번째 교차검증 수행
# ## 20번째 교차검증 수행
# ## 30번째 교차검증 수행
# ## 40번째 교차검증 수행
# ## 50번째 교차검증 수행
# ## 60번째 교차검증 수행
# ## 70번째 교차검증 수행
# ## 80번째 교차검증 수행
# ## 90번째 교차검증 수행
# ## 100번째 교차검증 수행
# ## 110번째 교차검증 수행
# ## 120번째 교차검증 수행
# ## 130번째 교차검증 수행
# ## 140번째 교차검증 수행
# ## 150번째 교차검증 수행
# ## 160번째 교차검증 수행
# ## 170번째 교차검증 수행
# ## 180번째 교차검증 수행
# ## 190번째 교차검증 수행
# ## 200번째 교차검증 수행
# ## 210번째 교차검증 수행
# ## 220번째 교차검증 수행
# ## 230번째 교차검증 수행
# ## 240번째 교차검증 수행
# ## 250번째 교차검증 수행
# ## 260번째 교차검증 수행
# ## 270번째 교차검증 수행
# ## 280번째 교차검증 수행
# ## 290번째 교차검증 수행
# ## 300번째 교차검증 수행
# ## 310번째 교차검증 수행
# ## 320번째 교차검증 수행
# ## 330번째 교차검증 수행
# ## 340번째 교차검증 수행
# ## 350번째 교차검증 수행
# ## 360번째 교차검증 수행

# %%
# # 364번 각 교차검증할 때마다 담은 Train 데이터에 대한 MAE값들의 평균 값
# TRAIN_MAE = np.array(train_mae_lst).mean()
# TEST_DF = pd.DataFrame()
# TEST_DF['y_true'] = np.array(test_y_lst)
# TEST_DF['y_pred'] = np.array(test_pred_lst)

# TEST_DF['score'] = 0
# TEST_DF.loc[abs(TEST_DF['y_true']-TEST_DF['y_pred']) < 1e5, 'score'] = 1
# TEST_DF = TEST_DF.set_index(dataset.iloc[len(dataset)-365:].index)
# TEST_MAE = mean_absolute_error(TEST_DF['y_true'], TEST_DF['y_pred'])
# TEST_ACC = TEST_DF['score'].mean() * 100

# print(f"## 365번 교차검증에 대한 Train 데이터 MAE:{TRAIN_MAE/1e4: .0f}만원")
# print()
# print(f"## 365번 교차검증에 대한 Test 데이터 MAE:{TEST_MAE/1e4: .0f}만원")
# print()
# print(f"## 365번 교차검증 후 365번의 예측에 대해서 오차 10만원 미만으로 예측한 데이터 비율:{TEST_ACC: .2f}%")

# # Graph label and prediction
# plt.figure(figsize=(12, 7))
# sns.lineplot(data=TEST_DF[['y_true', 'y_pred']])
# plt.title("실제값과 예측값 Line Graph", fontsize=20)
# plt.xlabel("날짜", fontsize=17)
# plt.ylabel("MAE Error", fontsize=17)
# plt.legend(['Label', 'Predicted'])
# plt.show()
# Out:
# ## 365번 교차검증에 대한 Train 데이터 MAE: 7만원
#
# ## 365번 교차검증에 대한 Test 데이터 MAE: 21만원
#
# ## 365번 교차검증 후 365번의 예측에 대해서 오차 10만원 미만으로 예측한 데이터 비율: 38.90%

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lr_reg = LinearRegression()

test_df, train_cv_mae = evaluate_cv_predict(dataframe=dataset, regressor=lr_reg)
# Out:
# ## 365번 교차검증 수행 시간: 4.717142105102539
#
# ## 365번 교차검증에 대한 Train 데이터 MAE: 28만원
#
# ## 365번 교차검증에 대한 Test 데이터 MAE: 28만원
#
# ## 365번 교차검증 후 365번의 예측에 대해서 오차 10만원 미만으로 예측한 데이터 비율: 30.68%

# %% [markdown]
# ### Polynomial Linear Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline

# 1차적인 모델링 수행했을 때 2차항이 가장 최적이었으므로 2차항으로 설정
poly_reg = Pipeline([('poly', PolynomialFeatures(degree=2,
                                                include_bias=True)),
                    ('linear', LinearRegression())])

test_df, train_cv_mae = evaluate_cv_predict(dataframe=dataset,
                                           regressor=poly_reg)
# Out:
# ## 365번 교차검증 수행 시간: 8.714577913284302
#
# ## 365번 교차검증에 대한 Train 데이터 MAE: 23만원
#
# ## 365번 교차검증에 대한 Test 데이터 MAE: 25만원
#
# ## 365번 교차검증 후 365번의 예측에 대해서 오차 10만원 미만으로 예측한 데이터 비율: 36.16%

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

rf_reg = RandomForestRegressor()

test_df, train_cv_mae = evaluate_cv_predict(dataframe=dataset,
                                           regressor=rf_reg)
# Out:
# ## 10번째 교차검증 수행
# ## 20번째 교차검증 수행
# ## 30번째 교차검증 수행
# ## 40번째 교차검증 수행
# ## 50번째 교차검증 수행
# ## 60번째 교차검증 수행
# ## 70번째 교차검증 수행
# ## 80번째 교차검증 수행
# ## 90번째 교차검증 수행
# ## 100번째 교차검증 수행
# ## 110번째 교차검증 수행
# ## 120번째 교차검증 수행
# ## 130번째 교차검증 수행
# ## 140번째 교차검증 수행
# ## 150번째 교차검증 수행
# ## 160번째 교차검증 수행
# ## 170번째 교차검증 수행
# ## 180번째 교차검증 수행
# ## 190번째 교차검증 수행
# ## 200번째 교차검증 수행
# ## 210번째 교차검증 수행
# ## 220번째 교차검증 수행
# ## 230번째 교차검증 수행
# ## 240번째 교차검증 수행
# ## 250번째 교차검증 수행
# ## 260번째 교차검증 수행
# ## 270번째 교차검증 수행
# ## 280번째 교차검증 수행
# ## 290번째 교차검증 수행
# ## 300번째 교차검증 수행
# ## 310번째 교차검증 수행
# ## 320번째 교차검증 수행
# ## 330번째 교차검증 수행
# ## 340번째 교차검증 수행
# ## 350번째 교차검증 수행
# ## 360번째 교차검증 수행
# ## 365번 교차검증 수행 시간: 609.8276000022888
#
# ## 365번 교차검증에 대한 Train 데이터 MAE: 7만원
#
# ## 365번 교차검증에 대한 Test 데이터 MAE: 21만원
#
# ## 365번 교차검증 후 365번의 예측에 대해서 오차 10만원 미만으로 예측한 데이터 비율: 41.37%

# %% [markdown]
# ### XGBoost Regressor

# %%
from xgboost import XGBRegressor

xgb_reg = XGBRegressor()

test_df, train_cv_mae = evaluate_cv_predict(dataframe=dataset,
                                          regressor=xgb_reg)
# Out:
# [19:29:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 10번째 교차검증 수행
# [19:29:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 20번째 교차검증 수행
# [19:29:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 30번째 교차검증 수행
# [19:29:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 40번째 교차검증 수행
# [19:29:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 50번째 교차검증 수행
# [19:29:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 60번째 교차검증 수행
# [19:29:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 70번째 교차검증 수행
# [19:29:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 80번째 교차검증 수행
# [19:29:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 90번째 교차검증 수행
# [19:29:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 100번째 교차검증 수행
# [19:29:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 110번째 교차검증 수행
# [19:29:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 120번째 교차검증 수행
# [19:29:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 130번째 교차검증 수행
# [19:29:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 140번째 교차검증 수행
# [19:29:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 150번째 교차검증 수행
# [19:29:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:29:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 160번째 교차검증 수행
# [19:30:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 170번째 교차검증 수행
# [19:30:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 180번째 교차검증 수행
# [19:30:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 190번째 교차검증 수행
# [19:30:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 200번째 교차검증 수행
# [19:30:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 210번째 교차검증 수행
# [19:30:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 220번째 교차검증 수행
# [19:30:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 230번째 교차검증 수행
# [19:30:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 240번째 교차검증 수행
# [19:30:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 250번째 교차검증 수행
# [19:30:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 260번째 교차검증 수행
# [19:30:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 270번째 교차검증 수행
# [19:30:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 280번째 교차검증 수행
# [19:30:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 290번째 교차검증 수행
# [19:30:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 300번째 교차검증 수행
# [19:30:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 310번째 교차검증 수행
# [19:30:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 320번째 교차검증 수행
# [19:30:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 330번째 교차검증 수행
# [19:30:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 340번째 교차검증 수행
# [19:30:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 350번째 교차검증 수행
# [19:30:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 360번째 교차검증 수행
# [19:30:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:30:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 365번 교차검증 수행 시간: 85.68236994743347
#
# ## 365번 교차검증에 대한 Train 데이터 MAE: 15만원
#
# ## 365번 교차검증에 대한 Test 데이터 MAE: 20만원
#
# ## 365번 교차검증 후 365번의 예측에 대해서 오차 10만원 미만으로 예측한 데이터 비율: 39.18%

# %% [markdown]
# ### LightGBM

# %%
from lightgbm import LGBMRegressor

lgb_reg = LGBMRegressor()

test_df, train_cv_mae = evaluate_cv_predict(dataframe=dataset,
                                          regressor=lgb_reg)
# Out:
# ## 10번째 교차검증 수행
# ## 20번째 교차검증 수행
# ## 30번째 교차검증 수행
# ## 40번째 교차검증 수행
# ## 50번째 교차검증 수행
# ## 60번째 교차검증 수행
# ## 70번째 교차검증 수행
# ## 80번째 교차검증 수행
# ## 90번째 교차검증 수행
# ## 100번째 교차검증 수행
# ## 110번째 교차검증 수행
# ## 120번째 교차검증 수행
# ## 130번째 교차검증 수행
# ## 140번째 교차검증 수행
# ## 150번째 교차검증 수행
# ## 160번째 교차검증 수행
# ## 170번째 교차검증 수행
# ## 180번째 교차검증 수행
# ## 190번째 교차검증 수행
# ## 200번째 교차검증 수행
# ## 210번째 교차검증 수행
# ## 220번째 교차검증 수행
# ## 230번째 교차검증 수행
# ## 240번째 교차검증 수행
# ## 250번째 교차검증 수행
# ## 260번째 교차검증 수행
# ## 270번째 교차검증 수행
# ## 280번째 교차검증 수행
# ## 290번째 교차검증 수행
# ## 300번째 교차검증 수행
# ## 310번째 교차검증 수행
# ## 320번째 교차검증 수행
# ## 330번째 교차검증 수행
# ## 340번째 교차검증 수행
# ## 350번째 교차검증 수행
# ## 360번째 교차검증 수행
# ## 365번 교차검증 수행 시간: 46.27240180969238
#
# ## 365번 교차검증에 대한 Train 데이터 MAE: 14만원
#
# ## 365번 교차검증에 대한 Test 데이터 MAE: 22만원
#
# ## 365번 교차검증 후 365번의 예측에 대해서 오차 10만원 미만으로 예측한 데이터 비율: 41.37%

# %% [markdown]
# ### MLP Regressor

# %%
from sklearn.neural_network import MLPRegressor

mlp_reg = MLPRegressor()

test_df, test_cv_mae = evaluate_cv_predict(dataframe=dataset,
                                          regressor=mlp_reg)
# Out:
# ## 10번째 교차검증 수행
# ## 20번째 교차검증 수행
# ## 30번째 교차검증 수행
# ## 40번째 교차검증 수행
# ## 50번째 교차검증 수행
# ## 60번째 교차검증 수행
# ## 70번째 교차검증 수행
# ## 80번째 교차검증 수행
# ## 90번째 교차검증 수행
# ## 100번째 교차검증 수행
# ## 110번째 교차검증 수행
# ## 120번째 교차검증 수행
# ## 130번째 교차검증 수행
# ## 140번째 교차검증 수행
# ## 150번째 교차검증 수행
# ## 160번째 교차검증 수행
# ## 170번째 교차검증 수행
# ## 180번째 교차검증 수행
# ## 190번째 교차검증 수행
# ## 200번째 교차검증 수행
# ## 210번째 교차검증 수행
# ## 220번째 교차검증 수행
# ## 230번째 교차검증 수행
# ## 240번째 교차검증 수행
# ## 250번째 교차검증 수행
# ## 260번째 교차검증 수행
# ## 270번째 교차검증 수행
# ## 280번째 교차검증 수행
# ## 290번째 교차검증 수행
# ## 300번째 교차검증 수행
# ## 310번째 교차검증 수행
# ## 320번째 교차검증 수행
# ## 330번째 교차검증 수행
# ## 340번째 교차검증 수행
# ## 350번째 교차검증 수행
# ## 360번째 교차검증 수행
# ## 365번 교차검증 수행 시간: 375.87828612327576
#
# ## 365번 교차검증에 대한 Train 데이터 MAE: 71만원
#
# ## 365번 교차검증에 대한 Test 데이터 MAE: 66만원
#
# ## 365번 교차검증 후 365번의 예측에 대해서 오차 10만원 미만으로 예측한 데이터 비율: 0.00%

# %% [markdown]
# ## PLS Regression
#
# - 최적의 주성분 개수는 3개

# %%
from sklearn.cross_decomposition import PLSRegression

pls_reg = PLSRegression(n_components=3)

test_df, train_cv_mae = evaluate_cv_predict(dataframe=dataset,
                                          regressor=pls_reg)
# Out:
# ## 10번째 교차검증 수행
# ## 20번째 교차검증 수행
# ## 30번째 교차검증 수행
# ## 40번째 교차검증 수행
# ## 50번째 교차검증 수행
# ## 60번째 교차검증 수행
# ## 70번째 교차검증 수행
# ## 80번째 교차검증 수행
# ## 90번째 교차검증 수행
# ## 100번째 교차검증 수행
# ## 110번째 교차검증 수행
# ## 120번째 교차검증 수행
# ## 130번째 교차검증 수행
# ## 140번째 교차검증 수행
# ## 150번째 교차검증 수행
# ## 160번째 교차검증 수행
# ## 170번째 교차검증 수행
# ## 180번째 교차검증 수행
# ## 190번째 교차검증 수행
# ## 200번째 교차검증 수행
# ## 210번째 교차검증 수행
# ## 220번째 교차검증 수행
# ## 230번째 교차검증 수행
# ## 240번째 교차검증 수행
# ## 250번째 교차검증 수행
# ## 260번째 교차검증 수행
# ## 270번째 교차검증 수행
# ## 280번째 교차검증 수행
# ## 290번째 교차검증 수행
# ## 300번째 교차검증 수행
# ## 310번째 교차검증 수행
# ## 320번째 교차검증 수행
# ## 330번째 교차검증 수행
# ## 340번째 교차검증 수행
# ## 350번째 교차검증 수행
# ## 360번째 교차검증 수행
# ## 365번 교차검증 수행 시간: 5.502496004104614
#
# ## 365번 교차검증에 대한 Train 데이터 MAE: 29만원
#
# ## 365번 교차검증에 대한 Test 데이터 MAE: 29만원
#
# ## 365번 교차검증 후 365번의 예측에 대해서 오차 10만원 미만으로 예측한 데이터 비율: 26.03%

# %% [markdown]
# ### Hybrid Voting

# %%
from sklearn.ensemble import VotingRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

hb_vote = VotingRegressor(estimators=[('rf', RandomForestRegressor()),
                                     ('xgb', XGBRegressor()),
                                     ('lgbm', LGBMRegressor())])

test_df, train_cv_mae = evaluate_cv_predict(dataframe=dataset,
                                          regressor=hb_vote)
# Out:
# [19:52:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 10번째 교차검증 수행
# [19:53:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 20번째 교차검증 수행
# [19:53:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 30번째 교차검증 수행
# [19:53:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:53:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 40번째 교차검증 수행
# [19:54:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 50번째 교차검증 수행
# [19:54:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 60번째 교차검증 수행
# [19:54:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:54:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 70번째 교차검증 수행
# [19:55:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 80번째 교차검증 수행
# [19:55:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 90번째 교차검증 수행
# [19:55:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 100번째 교차검증 수행
# [19:56:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 110번째 교차검증 수행
# [19:56:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 120번째 교차검증 수행
# [19:56:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 130번째 교차검증 수행
# [19:57:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 140번째 교차검증 수행
# [19:57:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 150번째 교차검증 수행
# [19:57:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 160번째 교차검증 수행
# [19:57:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 170번째 교차검증 수행
# [19:58:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 180번째 교차검증 수행
# [19:58:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 190번째 교차검증 수행
# [19:58:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 200번째 교차검증 수행
# [19:59:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 210번째 교차검증 수행
# [19:59:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 220번째 교차검증 수행
# [19:59:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 230번째 교차검증 수행
# [20:00:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 240번째 교차검증 수행
# [20:00:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 250번째 교차검증 수행
# [20:00:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 260번째 교차검증 수행
# [20:01:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 270번째 교차검증 수행
# [20:01:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 280번째 교차검증 수행
# [20:01:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 290번째 교차검증 수행
# [20:02:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 300번째 교차검증 수행
# [20:02:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 310번째 교차검증 수행
# [20:02:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 320번째 교차검증 수행
# [20:03:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 330번째 교차검증 수행
# [20:03:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 340번째 교차검증 수행
# [20:03:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 350번째 교차검증 수행
# [20:04:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 360번째 교차검증 수행
# [20:04:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 365번 교차검증 수행 시간: 702.3201060295105
#
# ## 365번 교차검증에 대한 Train 데이터 MAE: 12만원
#
# ## 365번 교차검증에 대한 Test 데이터 MAE: 20만원
#
# ## 365번 교차검증 후 365번의 예측에 대해서 오차 10만원 미만으로 예측한 데이터 비율: 41.64%

# %% [markdown]
# ### PCA 수행 후 LightGBM
#
# - 성능이 상위 모델에 속하여 속도가 빠른 LightGBM으로 선정
# - 최적의 주성분 개수 7개로 선정

# %%
from sklearn.decomposition import PCA
from lightgbm import LGBMRegressor

# dataframe에는 전처리된 데이터프레임 넣어야 함!
def evaluate_cv_pca_predict(dataframe, regressor):
    start_time = time.time()

    # 교차검증 1번 수행할 때마다 예측값 담을 리스트
    train_mae_lst = []  # 학습 데이터에 대한 MAE 담기 for overfitting 여부 확인
    test_pred_lst = []  # 비교하기 위해 1개의 미래 데이터에 대한 예측값 담기
    test_y_lst = []     # 비교하기 위해 1개의 미래 데이터에 대한 실제값 담기


    TRAIN_SPLIT = len(dataset) - 365
    for i in range(0, len(dataset)-(TRAIN_SPLIT)):
        if i % 10 == 0 and i > 0:
            print(f"## {i}번째 교차검증 수행")
        dataset['target'] = np.append(np.array(dataset['일매출'][1:]), 0)
        train = dataset.iloc[:i+TRAIN_SPLIT-1] # dataframe
        test = dataset.iloc[i+TRAIN_SPLIT-1] # Series
        test_y_lst.append(test[-1]) # Target값 저장
        test = pd.DataFrame(data=test.values.reshape(1, -1),
                           columns=test.index) # Convert Series to Dataframe
        X_train, y_train = train.iloc[:, :-1], train.iloc[:, -1]
        X_test, y_test = test.iloc[:, :-1], test.iloc[:, -1]

        # PCA
        pca = PCA(n_components=7)
        pca_cols = [f"PCA{p+1}" for p in range(0, 7)]
        X_train = pd.DataFrame(pca.fit_transform(X_train),
                              columns=pca_cols,
                              index=X_train.index)
        X_test = pd.DataFrame(pca.transform(X_test),
                             columns=pca_cols,
                             index=X_test.index)

        # fitting
        model = regressor
        model.fit(X_train, y_train)
        # predict
        train_pred = model.predict(X_train)
        test_pred = model.predict(X_test)
        # Evaluate
        train_mae = mean_absolute_error(y_train, train_pred)
        train_mae_lst.append(train_mae)
        test_pred_lst.append(test_pred[0])
    end_time = time.time() - start_time
    
    # 364번 각 교차검증할 때마다 담은 Train 데이터에 대한 MAE값들의 평균 값
    TRAIN_MAE = np.array(train_mae_lst).mean()
    TEST_DF = pd.DataFrame()
    TEST_DF['y_true'] = np.array(test_y_lst)
    TEST_DF['y_pred'] = np.array(test_pred_lst)

    TEST_DF['score'] = 0
    TEST_DF.loc[abs(TEST_DF['y_true']-TEST_DF['y_pred']) < 1e5, 'score'] = 1
    TEST_DF = TEST_DF.set_index(dataset.iloc[len(dataset)-365:].index)
    TEST_MAE = mean_absolute_error(TEST_DF['y_true'], TEST_DF['y_pred'])
    TEST_ACC = TEST_DF['score'].mean() * 100

    print("## 365번 교차검증 수행 시간:", end_time)
    print()
    print(f"## 365번 교차검증에 대한 Train 데이터 MAE:{TRAIN_MAE/1e4: .0f}만원")
    print()
    print(f"## 365번 교차검증에 대한 Test 데이터 MAE:{TEST_MAE/1e4: .0f}만원")
    print()
    print(f"## 365번 교차검증 후 365번의 예측에 대해서 오차 10만원 미만으로 예측한 데이터 비율:{TEST_ACC: .2f}%")

    # Graph label and prediction
    plt.figure(figsize=(12, 7))
    sns.lineplot(data=TEST_DF[['y_true', 'y_pred']])
    plt.title("실제값과 예측값 Line Graph", fontsize=20)
    plt.xlabel("날짜", fontsize=17)
    plt.ylabel("MAE Error", fontsize=17)
    plt.legend(['Label', 'Predicted'])
    plt.show()
    
    return TEST_DF, TRAIN_MAE

#### Modeling after PCA ####
lgb_reg = LGBMRegressor()
test_df, train_cv_mae = evaluate_cv_pca_predict(dataframe=dataset,
                                               regressor=lgb_reg)
# Out:
# ## 10번째 교차검증 수행
# ## 20번째 교차검증 수행
# ## 30번째 교차검증 수행
# ## 40번째 교차검증 수행
# ## 50번째 교차검증 수행
# ## 60번째 교차검증 수행
# ## 70번째 교차검증 수행
# ## 80번째 교차검증 수행
# ## 90번째 교차검증 수행
# ## 100번째 교차검증 수행
# ## 110번째 교차검증 수행
# ## 120번째 교차검증 수행
# ## 130번째 교차검증 수행
# ## 140번째 교차검증 수행
# ## 150번째 교차검증 수행
# ## 160번째 교차검증 수행
# ## 170번째 교차검증 수행
# ## 180번째 교차검증 수행
# ## 190번째 교차검증 수행
# ## 200번째 교차검증 수행
# ## 210번째 교차검증 수행
# ## 220번째 교차검증 수행
# ## 230번째 교차검증 수행
# ## 240번째 교차검증 수행
# ## 250번째 교차검증 수행
# ## 260번째 교차검증 수행
# ## 270번째 교차검증 수행
# ## 280번째 교차검증 수행
# ## 290번째 교차검증 수행
# ## 300번째 교차검증 수행
# ## 310번째 교차검증 수행
# ## 320번째 교차검증 수행
# ## 330번째 교차검증 수행
# ## 340번째 교차검증 수행
# ## 350번째 교차검증 수행
# ## 360번째 교차검증 수행
# ## 365번 교차검증 수행 시간: 40.936474084854126
#
# ## 365번 교차검증에 대한 Train 데이터 MAE: 18만원
#
# ## 365번 교차검증에 대한 Test 데이터 MAE: 27만원
#
# ## 365번 교차검증 후 365번의 예측에 대해서 오차 10만원 미만으로 예측한 데이터 비율: 34.52%

# %% [markdown]
# ### Deep Learning - LSTM

# %%
import math
import tensorflow as tf

no_scale_cols = ['요일', '설_추석_가중치', '일반공휴일가중치', 'target']
scale_cols = ['일매출', '한우가격', '육우가격', '돼지탕박가격', '평균상대습도', '최고기온', '평균풍속', '최대풍속',
             '일사량', '일강수량']

DL_df = dataset.copy()
DL_df['target'] = np.append(np.array(DL_df.iloc[1:, 1]), 0)
DL_df = DL_df.iloc[:-1, :]

# Train, Test Scaling
TRAIN_SPLIT = math.floor(DL_df.shape[0] * 0.9)

no_scale_feature = DL_df[no_scale_cols].values
scale_feature = DL_df[scale_cols].values
# Scaling
scale_mean = scale_feature[:TRAIN_SPLIT].mean(axis=0)
scale_std = scale_feature[:TRAIN_SPLIT].std(axis=0)
scale_feature = (scale_feature - scale_mean)/scale_std

print('No scale shape:', no_scale_feature.shape)
print("scale shape:", scale_feature.shape)
# Out:
# No scale shape: (2915, 4)
# scale shape: (2915, 10)

# %%
dataset = np.concatenate((no_scale_feature, scale_feature), axis=1)
print("Merge shape:", dataset.shape)
# Out:
# Merge shape: (2915, 14)

# %%
# Single step model
# history_size : 과거의 몇 개 데이터를 볼건지
# step : 몇 단계의 미래값을 예측할지(현재 문제에선 다음단계니까 step=1)
# target_size : 예측할 값의 size(현재 문제에선 다음날 하루예측이니까 1)

def multivariate_data(dataset, target, start_idx, end_idx,
                     history_size, target_size, step,
                     single_step=False):
    data = []
    labels = []
    start_idx = start_idx + history_size
    # 마지막 인덱스 지정하지 않으면 -> 그런데 내가 이미 마지막 데이터짤라놓았음..!
    if end_idx is None:
        end_idx = len(dataset) - target_size
    
    for i in range(start_idx, end_idx):
        # i-history_size ~ i-1까지 step 간격의 인덱스
        indices = range(i - history_size, i, step)
        data.append(dataset[indices])
        
        if single_step:
            labels.append(target[i+target_size-1]) 
    return np.asarray(data), np.asarray(labels)

# %%
target = DL_df.iloc[:,-1].values
past_history = 7
future_target = 1
step = 1

X_train, y_train = multivariate_data(dataset, target, 0,
                                    TRAIN_SPLIT, past_history,
                                    future_target, step,
                                    single_step=True)
X_test, y_test = multivariate_data(dataset, target, TRAIN_SPLIT,
                                  len(dataset), past_history,
                                  future_target, step,
                                  single_step=True)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (2616, 7, 14) (2616,)
# (285, 7, 14) (285,)

# %%
X_train_data = tf.data.Dataset.from_tensor_slices((X_train, y_train))
X_test_data = tf.data.Dataset.from_tensor_slices((X_test, y_test))

model = tf.keras.Sequential([
    tf.keras.layers.Conv1D(filters=32, kernel_size=5, strides=1,
                          padding='causal'),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(units=64,
                                                       return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(units=32)),
    tf.keras.layers.Dense(64),
    tf.keras.layers.Dense(32),
    tf.keras.layers.Dense(16),
    tf.keras.layers.Dense(4),
    tf.keras.layers.Dense(1)
])
model.compile(optimizer='adam', loss='mae')
history = model.fit(X_train, y_train, epochs=30, verbose=True)
# Out:
# WARNING:tensorflow:From /Users/younghun/opt/anaconda3/envs/venvforpython/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /Users/younghun/opt/anaconda3/envs/venvforpython/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /Users/younghun/opt/anaconda3/envs/venvforpython/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /Users/younghun/opt/anaconda3/envs/venvforpython/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /Users/younghun/opt/anaconda3/envs/venvforpython/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/30
# 2616/2616 [==============================] - 3s 1ms/sample - loss: 730974.3150
# Epoch 2/30
# 2616/2616 [==============================] - 1s 401us/sample - loss: 711338.7404
# Epoch 3/30
# 2616/2616 [==============================] - 1s 410us/sample - loss: 521585.2376
# Epoch 4/30
# 2616/2616 [==============================] - 1s 429us/sample - loss: 354305.7536
# Epoch 5/30
# 2616/2616 [==============================] - 1s 433us/sample - loss: 349732.5278
# Epoch 6/30
# 2616/2616 [==============================] - 1s 441us/sample - loss: 341189.7964
# Epoch 7/30
# 2616/2616 [==============================] - 1s 453us/sample - loss: 336733.4546
# Epoch 8/30
# 2616/2616 [==============================] - 1s 425us/sample - loss: 340046.1081
# Epoch 9/30
# 2616/2616 [==============================] - 1s 442us/sample - loss: 335470.8406
# Epoch 10/30
# 2616/2616 [==============================] - 1s 441us/sample - loss: 338263.6391
# Epoch 11/30
# 2616/2616 [==============================] - 1s 438us/sample - loss: 340042.7419
# Epoch 12/30
# 2616/2616 [==============================] - 1s 442us/sample - loss: 337011.1320
# Epoch 13/30
# 2616/2616 [==============================] - 1s 422us/sample - loss: 335348.0726
# Epoch 14/30
# 2616/2616 [==============================] - 1s 417us/sample - loss: 337852.1745
# Epoch 15/30
# 2616/2616 [==============================] - 1s 447us/sample - loss: 334929.7737
# Epoch 16/30
# 2616/2616 [==============================] - 1s 457us/sample - loss: 331522.9553
# Epoch 17/30
# 2616/2616 [==============================] - 1s 440us/sample - loss: 337848.6442
# Epoch 18/30
# 2616/2616 [==============================] - 1s 454us/sample - loss: 337895.5956
# Epoch 19/30
# 2616/2616 [==============================] - 1s 446us/sample - loss: 329701.2719
# Epoch 20/30
# 2616/2616 [==============================] - 1s 461us/sample - loss: 336320.2235
# Epoch 21/30
# 2616/2616 [==============================] - 1s 438us/sample - loss: 331768.8145
# Epoch 22/30
# 2616/2616 [==============================] - 1s 439us/sample - loss: 337428.2618
# Epoch 23/30
# 2616/2616 [==============================] - 1s 431us/sample - loss: 341996.3538
# Epoch 24/30
# 2616/2616 [==============================] - 1s 421us/sample - loss: 334961.4137
# Epoch 25/30
# 2616/2616 [==============================] - 1s 430us/sample - loss: 335882.2851
# Epoch 26/30
# 2616/2616 [==============================] - 1s 431us/sample - loss: 333853.9171
# Epoch 27/30
# 2616/2616 [==============================] - 1s 438us/sample - loss: 341408.1456
# Epoch 28/30
# 2616/2616 [==============================] - 1s 430us/sample - loss: 333901.6521
# Epoch 29/30
# 2616/2616 [==============================] - 1s 431us/sample - loss: 335529.0685
# Epoch 30/30
# 2616/2616 [==============================] - 1s 430us/sample - loss: 340976.2375

# %%
# 메트릭 얻는 함수
from sklearn.metrics import mean_absolute_error, mean_squared_error

def get_metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    return mae, rmse

# Predict
train_df = pd.DataFrame(data=y_train, columns=['target'])
train_df['y_pred'] = model.predict(X_train).reshape(-1,)
test_df = pd.DataFrame(data=y_test, columns=['target'])
test_df['y_pred'] = model.predict(X_test).reshape(-1,)
# estimate accuracy
train_df['score'] = 0
train_df.loc[abs(train_df['target']-train_df['y_pred']) < 1e5, 'score'] = 1
test_df['score'] = 0
test_df.loc[abs(test_df['target']-test_df['y_pred']) < 1e5, 'score'] = 1

train_mae, _ = get_metrics(train_df['target'], train_df['y_pred'])
train_acc = train_df['score'].mean() * 100
test_mae, _ = get_metrics(test_df['target'], test_df['y_pred'])
test_acc = test_df['score'].mean() * 100

print(f"# Train MAE: {train_mae :.0f}\n# Train Accuracy: {train_acc :.2f}")
print(f"# Test MAE: {test_mae :.0f}\n# Test Accuracy: {test_acc :.2f}")
# Out:
# # Train MAE: 336004
# # Train Accuracy: 37.00
# # Test MAE: 260057
# # Test Accuracy: 38.95

# %% [markdown]
# ---

# %% [markdown]
# ## 2009년~2013년 추가된 데이터로 재 모델링

# %% [markdown]
# ### 추가된 데이터 모으고 전처리 하는 코드

# %%
import pymysql
import pandas as pd
from sklearn.impute import KNNImputer
import holidays
from datetime import date
from itertools import chain


db = pymysql.connect(host='localhost', user='younghun',
                    password='watson1259', db='beef_pork_db',
                    charset='utf8')
cursor = db.cursor()
# 소 데이터에서 2011년 3월 3일부터 '중부권'이 등장
beef_sql = "SELECT * FROM beef_prices WHERE 날짜 < '2011-03-03' AND 지역 = '전국'\
            UNION\
            SELECT * FROM beef_prices WHERE 날짜 >= '2011-03-03' AND 지역 = '중부권'\
            ORDER BY 날짜"
pork_sql = "SELECT DISTINCT * FROM pork_prices ORDER BY 날짜"

beef_df = pd.read_sql(beef_sql, db)
pork_df = pd.read_sql(pork_sql, db)

###### 소 변수 전처리 ######
hanwoo_df = beef_df[beef_df['종류'] == '한우']
yukwoo_df = beef_df[beef_df['종류'] == '육우']
# 현재 한우, 육우 둘다 중복된 row들 없음 -> 이제 중간 비어있는 값들은 주말(공휴일)로 이전의 값으로 대체!
hanwoo_df = hanwoo_df.rename(columns={'종류': '한우', '가격': '한우가격'})
yukwoo_df = yukwoo_df.rename(columns={'종류': '육우', '가격': '육우가격'})
 
raw_date_df = pd.DataFrame(pd.date_range(start='2009-01-01', end='2021-03-24', freq='D'))
raw_date_df = raw_date_df.rename(columns={0: '날짜'})
hanwoo_df = raw_date_df.merge(hanwoo_df, how='left')
hanwoo_df = hanwoo_df[['날짜', '한우가격']]
yukwoo_df = raw_date_df.merge(yukwoo_df, how='left')
yukwoo_df = yukwoo_df[['날짜', '육우가격']]
hanwoo_df = hanwoo_df.fillna(method='ffill')
yukwoo_df = yukwoo_df.fillna(method='ffill')
merge_beef_df = hanwoo_df.merge(yukwoo_df, how='inner', on='날짜')

###### 돼지 변수 전처리 ######
cond_tang = pork_df['종류'] == '탕박'
cond_n = pork_df['지역'] == '전국'
pork_df = pork_df[(cond_tang)&(cond_n)]

raw_date_df = pd.DataFrame(pd.date_range(start='2009-01-01', end='2021-03-24', freq='D'))
raw_date_df = raw_date_df.rename(columns={0: '날짜'})

merge_pork_df = raw_date_df.merge(pork_df, how='left')
merge_pork_df = merge_pork_df.fillna(method='ffill')
merge_pork_df = merge_pork_df.rename(columns={'가격': '돼지탕박가격'})
merge_cols = ['날짜', '돼지탕박가격']
merge_pork_df = merge_pork_df[merge_cols]

##### 소 & 돼지 변수 병합 #####
beef_pork_df = merge_beef_df.merge(merge_pork_df, how='inner', on='날짜')

##### 아웃라이어 처리 #####
# 1. 육우가격이 비정상적으로 높을 때
cond0 = beef_pork_df['한우가격'] < beef_pork_df['육우가격']
cond1 = beef_pork_df['육우가격'] > 18000
beef_pork_df.loc[(cond0|cond1), '육우가격'] = beef_pork_df.loc[(cond0|cond1)]['한우가격'] * (10/18)
# 2. 한우가격이 비정상적으로 낮을 때(만원 이하)
cond2 = beef_pork_df['한우가격'] < 1e4
beef_pork_df.loc[cond2, '한우가격'] = beef_pork_df.loc[cond2]['육우가격'] * (18/10)

print("소, 돼지 데이터 shape:", beef_pork_df.shape)

db = pymysql.connect(host='localhost', user='younghun',
                    password='watson1259', db='weather_db',
                    charset='utf8')
cursor = db.cursor()

weather_sql = "SELECT DISTINCT 지역, 시간,\
                      NULLIF(평균기온, '') AS 평균기온,\
                      NULLIF(최저기온, '') AS 최저기온,\
                      NULLIF(최고기온, '') AS 최고기온,\
                      NULLIF(1시간최다강수량, '') AS 1시간최다강수량,\
                      NULLIF(일강수량, '') AS 일강수량,\
                      NULLIF(평균풍속, '') AS 평균풍속,\
                      NULLIF(최대풍속, '') AS 최대풍속,\
                      NULLIF(평균상대습도, '') AS 평균상대습도,\
                      NULLIF(최소상대습도, '') AS 최소상대습도,\
                      NULLIF(1시간최다일사량, '') AS 1시간최다일사량,\
                      NULLIF(일사량, '') AS 일사량\
                      FROM weather\
                      ORDER BY 시간"
weather = pd.read_sql(weather_sql, db)
weather = weather.rename(columns={'시간': '날짜'})

dataset = weather.copy()
dataset = dataset.drop(['1시간최다강수량'], axis=1)
dataset['일강수량'] = dataset['일강수량'].fillna(0.0)

avg_wind = dataset[['평균풍속', '최대풍속']] # 결측치:평균풍속
avg_humid = dataset[['평균상대습도', '최소상대습도', '최저기온', '일강수량', '평균기온', '최고기온']] # 결측치:평균상대습도
max_sun_h = dataset[['1시간최다일사량', '최고기온', '평균기온', '최저기온', '최소상대습도']] # 결측치:1시간최다일사량
max_sun = dataset[['일사량', '최고기온', '평균기온', '최저기온', '최소상대습도']] # 결측치:일사량

knn_datasets = [avg_wind, avg_humid, max_sun_h, max_sun]
after_datasets = []
for data in knn_datasets:
    imputer = KNNImputer(n_neighbors=5, weights='uniform', metric='nan_euclidean')
    imputer.fit(data.values)
    after_values = imputer.transform(data.values) # array
    after_dataset = pd.DataFrame(after_values, columns=data.columns)
    after_datasets.append(after_dataset)
concat_df = pd.concat([after_datasets[0], after_datasets[1], after_datasets[2], after_datasets[3]], axis=1)
concat_cols = concat_df.columns.tolist()
transform_dict = {}

for i, v in enumerate(concat_df.values.T):
    transform_dict[concat_cols[i]] = v
transform_df = pd.DataFrame(transform_dict)

standard_cols = set(dataset.columns) - set(transform_df.columns)
dataset = pd.concat([dataset[standard_cols], transform_df], axis=1)

weather = dataset.copy()
# 지역 칼럼은 삭제
weather = weather.drop('지역', axis=1)
print("날씨 데이터 shape:", weather.shape)

db = pymysql.connect(host='localhost', user='younghun',
                    password='watson1259', db='sales_db',
                    charset='utf8')
cursor = db.cursor()

sales_sql = "SELECT DISTINCT * FROM sales ORDER BY 날짜"
sales = pd.read_sql(sales_sql, db)

present_time = int(pd.Timestamp.now().strftime("%Y"))
kor_holidays = holidays.Korea(years=[d for d in range(2008, present_time+1)])

holidays_dates = []
holidays_names = []
for date, name in kor_holidays.items():
    holidays_dates.append(date)
    holidays_names.append(name)

holidays_df = pd.DataFrame({'공휴일날짜': holidays_dates,
                            '공휴일명': holidays_names}).sort_values(by='공휴일날짜')
holidays_df['공휴일날짜'] = pd.to_datetime(holidays_df['공휴일날짜'])

end_time = (pd.Timestamp.now() - pd.Timedelta(days=1)).strftime("%Y-%m-%d")
next_five_time = pd.date_range(start=end_time, freq='D', periods=6)[-1].strftime('%Y-%m-%d')
extra_datetime = pd.DataFrame(pd.date_range(start='2009-01-01', end=next_five_time, freq='D'),
                             columns=['가중치위한날짜'])
sales = extra_datetime.merge(sales, how='left', left_on='가중치위한날짜', right_on='날짜')
sales = sales.drop('날짜', axis=1)
sales = sales.rename(columns={'가중치위한날짜': '날짜'})
sales_holiday_df = sales.merge(holidays_df, how='left', left_on='날짜', right_on='공휴일날짜')
print("일매출 데이터 shape:", sales_holiday_df.shape)

hol_cols = ['날짜', '일매출', 'remark', '공휴일날짜', '공휴일명']
holidays_data = sales_holiday_df[hol_cols]
holidays_data['요일'] = holidays_data['날짜'].dt.day_name()
hol_cols = ['날짜', '요일','일매출', 'remark', '공휴일날짜', '공휴일명']
holidays_data = holidays_data[hol_cols]

lunar_chuseok = ["The day preceding of Lunar New Year's Day", "The day preceding of Chuseok"]
lunar_chuseok_dates = holidays_data[holidays_data['공휴일명'].isin(lunar_chuseok)]['날짜'].dt.strftime('%Y-%m-%d').values
lunar_chuseok_around_dates = []
for date in lunar_chuseok_dates:
    around = pd.date_range(end=date, freq='D', periods=6)
    lunar_chuseok_around_dates.append(around)
lunar_chuseok_arounds = list(chain.from_iterable(lunar_chuseok_around_dates))

lunar_chuseok_dict = {}
weight = 0
for around_date in lunar_chuseok_arounds:
    weight += 1
    if weight > 6:
        weight = 1
    lunar_chuseok_dict[around_date] = weight

    
# 추석, 설날 주변 날짜에 가중치 부여하는 함수 정의
def holidays_weights(df):
    df['설_추석_가중치'] = 0
    df['일반공휴일가중치'] = 0
    if df['날짜'] in list(lunar_chuseok_dict.keys()):
        df['설_추석_가중치'] = lunar_chuseok_dict[df['날짜']]
    return df

holidays_data = holidays_data.apply(holidays_weights, axis=1)
holidays_data.loc[(~holidays_data['공휴일명'].str.contains('Lunar|Chuseok', na=False))&(holidays_data['공휴일명'].notnull()), '일반공휴일가중치'] = 1

# 필요한 변수들만 추출하기
need_cols = ['날짜', '요일', '일매출', '설_추석_가중치', '일반공휴일가중치']
holidays_data = holidays_data[need_cols]

# 휴무 가중치를 부여하기 위해 5일 늘린 날짜를 기준으로 left join
beef_pork_weather = beef_pork_df.merge(weather, how='inner', on='날짜')
dataset = holidays_data.merge(beef_pork_weather, how='left', on='날짜')
# 다시 우리가 원하는 데이터프레임 형태로 만들기 위해 마지막 5개의 rows들은 제외하고 재할당
dataset = dataset.iloc[:-5]

days = dataset.groupby('요일')['일매출'].mean().index
means = dataset.groupby('요일')['일매출'].mean().values
weekdays_means = dict(zip(days, means))
weekdays_means

def replace_zero_sales(df):
    if df['일매출'] == 0:
        df['일매출'] = weekdays_means[df['요일']]
    return df
final_dataset = dataset.apply(replace_zero_sales, axis=1)

total = dataset.groupby('요일')['일매출'].mean().values.sum()
weekdays = dataset.groupby('요일')['일매출'].mean().index
values = np.round(dataset.groupby('요일')['일매출'].mean().values / total * 100, 2)
weekdays_dict = dict(zip(weekdays, values))

dataset['요일'] = dataset['요일'].map(weekdays_dict)

# remove multicolinearity
multi_cols = ['최소상대습도', '최저기온', '평균기온', '1시간최다일사량']
final_dataset = dataset.drop(multi_cols, axis=1)
final_dataset = final_dataset.set_index('날짜')

print("Final dataset:", final_dataset.shape)
# Out:
# 소, 돼지 데이터 shape: (4466, 4)
# 날씨 데이터 shape: (4466, 11)
# 일매출 데이터 shape: (4471, 5)
# Final dataset: (4466, 13)

# %% [markdown]
# ### 2020년 1년치 1개의 데이터씩 교차검증하는 함수

# %%
#### 1년치 교차검증 함수 만들기 ####
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
import time
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# dataframe에는 전처리된 데이터프레임 넣어야 함!
def evaluate_cv_predict(dataset, regressor):
    start_time = time.time()

    # 교차검증 1번 수행할 때마다 예측값 담을 리스트
    train_mae_lst = []  # 학습 데이터에 대한 MAE 담기 for overfitting 여부 확인
    test_pred_lst = []  # 비교하기 위해 1개의 미래 데이터에 대한 예측값 담기
    test_y_lst = []     # 비교하기 위해 1개의 미래 데이터에 대한 실제값 담기


    TRAIN_SPLIT = len(dataset) - 365
    for i in range(0, len(dataset)-(TRAIN_SPLIT)):
        if i % 10 == 0 and i > 0:
            print(f"## {i}번째 교차검증 수행")
        dataset['target'] = np.append(np.array(dataset['일매출'][1:]), 0)
        train = dataset.iloc[:i+TRAIN_SPLIT-1] # dataframe
        test = dataset.iloc[i+TRAIN_SPLIT-1] # Series
        test_y_lst.append(test[-1]) # Target값 저장
        test = pd.DataFrame(data=test.values.reshape(1, -1),
                           columns=test.index) # Convert Series to Dataframe
        X_train, y_train = train.iloc[:, :-1], train.iloc[:, -1]
        X_test, y_test = test.iloc[:, :-1], test.iloc[:, -1]

        # Scaling
        scaler = MinMaxScaler()
        no_scale_cols = ['요일', '설_추석_가중치', '일반공휴일가중치']
        scale_cols = ['일매출', '한우가격', '육우가격', '돼지탕박가격', '평균상대습도', '최고기온', '평균풍속', '최대풍속',
                      '일사량', '일강수량']

        X_train_scale = X_train[scale_cols]
        X_train_no_scale = X_train[no_scale_cols]
        X_test_scale = X_test[scale_cols]
        X_test_no_scale = X_test[no_scale_cols]

        X_train_scale = pd.DataFrame(scaler.fit_transform(X_train_scale),
                                     columns=X_train_scale.columns,
                                     index=X_train_scale.index)
        X_test_scale = pd.DataFrame(scaler.transform(X_test_scale),
                                    columns=X_test_scale.columns,
                                    index=X_test_scale.index)

        X_train = pd.concat([X_train_scale, X_train_no_scale], axis=1)
        X_test = pd.concat([X_test_scale, X_test_no_scale], axis=1)

        # fitting
        model = regressor
        model.fit(X_train, y_train)
        # predict
        train_pred = model.predict(X_train)
        test_pred = model.predict(X_test)
        # Evaluate
        train_mae = mean_absolute_error(y_train, train_pred)
        train_mae_lst.append(train_mae)
        test_pred_lst.append(test_pred[0])
    end_time = time.time() - start_time
    
    # 364번 각 교차검증할 때마다 담은 Train 데이터에 대한 MAE값들의 평균 값
    TRAIN_MAE = np.array(train_mae_lst).mean()
    TEST_DF = pd.DataFrame()
    TEST_DF['y_true'] = np.array(test_y_lst)
    TEST_DF['y_pred'] = np.array(test_pred_lst)

    TEST_DF['score'] = 0
    TEST_DF.loc[abs(TEST_DF['y_true']-TEST_DF['y_pred']) < 1e5, 'score'] = 1
    TEST_DF = TEST_DF.set_index(dataset.iloc[len(dataset)-365:].index)
    TEST_MAE = mean_absolute_error(TEST_DF['y_true'], TEST_DF['y_pred'])
    TEST_ACC = TEST_DF['score'].mean() * 100

    print("## 365번 교차검증 수행 시간:", end_time)
    print()
    print(f"## 365번 교차검증에 대한 Train 데이터 MAE:{TRAIN_MAE/1e4: .0f}만원")
    print()
    print(f"## 365번 교차검증에 대한 Test 데이터 MAE:{TEST_MAE/1e4: .0f}만원")
    print()
    print(f"## 365번 교차검증 후 365번의 예측에 대해서 오차 10만원 미만으로 예측한 데이터 비율:{TEST_ACC: .2f}%")

    # Graph label and prediction
    plt.figure(figsize=(12, 7))
    sns.lineplot(data=TEST_DF[['y_true', 'y_pred']])
    plt.title("실제값과 예측값 Line Graph", fontsize=20)
    plt.xlabel("날짜", fontsize=17)
    plt.ylabel("MAE Error", fontsize=17)
    plt.legend(['Label', 'Predicted'])
    plt.show()
    
    return TEST_DF, TRAIN_MAE

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

rf_reg = RandomForestRegressor()

test_df, train_cv_mae = evaluate_cv_predict(dataset=final_dataset,
                                           regressor=rf_reg)
# Out:
# ## 10번째 교차검증 수행
# ## 20번째 교차검증 수행
# ## 30번째 교차검증 수행
# ## 40번째 교차검증 수행
# ## 50번째 교차검증 수행
# ## 60번째 교차검증 수행
# ## 70번째 교차검증 수행
# ## 80번째 교차검증 수행
# ## 90번째 교차검증 수행
# ## 100번째 교차검증 수행
# ## 110번째 교차검증 수행
# ## 120번째 교차검증 수행
# ## 130번째 교차검증 수행
# ## 140번째 교차검증 수행
# ## 150번째 교차검증 수행
# ## 160번째 교차검증 수행
# ## 170번째 교차검증 수행
# ## 180번째 교차검증 수행
# ## 190번째 교차검증 수행
# ## 200번째 교차검증 수행
# ## 210번째 교차검증 수행
# ## 220번째 교차검증 수행
# ## 230번째 교차검증 수행
# ## 240번째 교차검증 수행
# ## 250번째 교차검증 수행
# ## 260번째 교차검증 수행
# ## 270번째 교차검증 수행
# ## 280번째 교차검증 수행
# ## 290번째 교차검증 수행
# ## 300번째 교차검증 수행
# ## 310번째 교차검증 수행
# ## 320번째 교차검증 수행
# ## 330번째 교차검증 수행
# ## 340번째 교차검증 수행
# ## 350번째 교차검증 수행
# ## 360번째 교차검증 수행
# ## 365번 교차검증 수행 시간: 993.1552860736847
#
# ## 365번 교차검증에 대한 Train 데이터 MAE: 7만원
#
# ## 365번 교차검증에 대한 Test 데이터 MAE: 20만원
#
# ## 365번 교차검증 후 365번의 예측에 대해서 오차 10만원 미만으로 예측한 데이터 비율: 39.45%

# %% [markdown]
# ### Hybrid Voting Regressor
# - Random Forest
# - XGBoost
# - LightGBM

# %%
from sklearn.ensemble import VotingRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

hb_vote = VotingRegressor([('rf', RandomForestRegressor()),
                          ('xgb', XGBRegressor()),
                          ('lgbm', LGBMRegressor())])

test_df, train_cv_mae = evaluate_cv_predict(dataset=final_dataset,
                                           regressor=hb_vote)
# Out:
# [15:40:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:40:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:40:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:40:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:40:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:40:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:40:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:40:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:40:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:40:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 10번째 교차검증 수행
# [15:40:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:40:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:40:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:40:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:40:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:40:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:40:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:40:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 20번째 교차검증 수행
# [15:41:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 30번째 교차검증 수행
# [15:41:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:41:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 40번째 교차검증 수행
# [15:42:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 50번째 교차검증 수행
# [15:42:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:42:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 60번째 교차검증 수행
# [15:43:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 70번째 교차검증 수행
# [15:43:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:43:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 80번째 교차검증 수행
# [15:44:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 90번째 교차검증 수행
# [15:44:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:44:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 100번째 교차검증 수행
# [15:45:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 110번째 교차검증 수행
# [15:45:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:46:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:46:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:46:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:46:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 120번째 교차검증 수행
# [15:46:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:46:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:46:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:46:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:46:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:46:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:46:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:46:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:46:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:46:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 130번째 교차검증 수행
# [15:46:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:46:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:46:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:46:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:46:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:47:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:47:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:47:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:47:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:47:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 140번째 교차검증 수행
# [15:47:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:47:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:47:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:47:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:47:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:47:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:47:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:47:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:47:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:47:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 150번째 교차검증 수행
# [15:47:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:47:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:47:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:47:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 160번째 교차검증 수행
# [15:48:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 170번째 교차검증 수행
# [15:48:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:48:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 180번째 교차검증 수행
# [15:49:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:49:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 190번째 교차검증 수행
# [15:49:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 200번째 교차검증 수행
# [15:50:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:50:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 210번째 교차검증 수행
# [15:51:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 220번째 교차검증 수행
# [15:51:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:51:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 230번째 교차검증 수행
# [15:52:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 240번째 교차검증 수행
# [15:52:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:52:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 250번째 교차검증 수행
# [15:53:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 260번째 교차검증 수행
# [15:53:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:53:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:54:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:54:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:54:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 270번째 교차검증 수행
# [15:54:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:54:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:54:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:54:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:54:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:54:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:54:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:54:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:54:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:54:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 280번째 교차검증 수행
# [15:54:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:54:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:54:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:54:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:54:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:55:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:55:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:55:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:55:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:55:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 290번째 교차검증 수행
# [15:55:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:55:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:55:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:55:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:55:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:55:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:55:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:55:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:55:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:55:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 300번째 교차검증 수행
# [15:55:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:55:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:55:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:56:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:56:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:56:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:56:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:56:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:56:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:56:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 310번째 교차검증 수행
# [15:56:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:56:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:56:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:56:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:56:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:56:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:56:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:56:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:56:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:56:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 320번째 교차검증 수행
# [15:56:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:56:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:57:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:57:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:57:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:57:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:57:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:57:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:57:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:57:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 330번째 교차검증 수행
# [15:57:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:57:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:57:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:57:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:57:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:57:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:57:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:57:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:57:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:57:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 340번째 교차검증 수행
# [15:58:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:58:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:58:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:58:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:58:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:58:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:58:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:58:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:58:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:58:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 350번째 교차검증 수행
# [15:58:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:58:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:58:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:58:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:58:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:58:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:58:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:58:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:59:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:59:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 360번째 교차검증 수행
# [15:59:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:59:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:59:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:59:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:59:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ## 365번 교차검증 수행 시간: 1154.4615128040314
#
# ## 365번 교차검증에 대한 Train 데이터 MAE: 12만원
#
# ## 365번 교차검증에 대한 Test 데이터 MAE: 19만원
#
# ## 365번 교차검증 후 365번의 예측에 대해서 오차 10만원 미만으로 예측한 데이터 비율: 40.55%

# %% [markdown]
# - 데이터를 추가한 후에는 Hybrid Voting 방법이 약간 성능이 앞섰지만 Random Forest가 압도적으로 Train MAE가 매우 낮은 상태..
# - ``Random Forest``
#     - 현재 오버피팅이 좀 심한 편. 하지만 앞으로 계속적인 데이터 추가로 인해 오버피팅을 해결할 수 있을 것으로 판단
# - ``Hybrid Voting``
#     - 오버피팅이 덜 심하지만 Random Forest 모델보다 Train MAE가 약간 높은 편..
# - **앞으로 데이터가 추가될 것이라는 점**과 **상대적으로 RF 모델이 더 단순한 모델**이므로 **``Random Forest Regressor``**로 최종 모델 선정!
# ---

# %% [markdown]
# ### Hyperparameter Tuning

# %%
final_dataset.head(2)
# Out:
#                요일       일매출  설_추석_가중치  일반공휴일가중치     한우가격    육우가격  돼지탕박가격  \
# 날짜
# 2009-01-01  12.57       0.0         0         1  14263.0  6760.0  3818.0
# 2009-01-02  15.32  666950.0         0         0  14937.0  7176.0  4312.0
#
#             평균풍속  최대풍속  평균상대습도  일강수량  최고기온    일사량    target
# 날짜
# 2009-01-01   1.9   4.2    53.8   0.0  -0.2  11.11  666950.0
# 2009-01-02   1.2   3.2    59.5   0.0   4.3  11.63  854000.0

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error

final_dataset['target'] = np.append(np.array(dataset['일매출'][1:]), 0) # make target variable
train_size = final_dataset.shape[0] - 5
tscv = TimeSeriesSplit(max_train_size=train_size,
                      test_size=1, n_splits=5)

grid = {'n_estimators': [50, 100, 300],
             'min_samples_split': [2, 10, 30]} # overfitting 방지

cv_count = [c for c in range(1, 366)]
param_lst = []
train_mae_lst = []
test_mae_lst = []

for train_idx, test_idx in tscv.split(final_dataset.iloc[:-1]):
    train = final_dataset.iloc[train_idx]
    test = final_dataset.iloc[test_idx]
    
    X_train, y_train = train.iloc[:, :-1], train.iloc[:, -1]
    X_test, y_test = test.iloc[:, :-1], test.iloc[:, -1]
    
    scaler = MinMaxScaler()
    no_scale_cols = ['요일', '설_추석_가중치', '일반공휴일가중치']
    scale_cols = ['일매출', '한우가격', '육우가격', '돼지탕박가격', '평균상대습도', '최고기온', '평균풍속', '최대풍속',
                  '일사량', '일강수량']

    X_train_scale = X_train[scale_cols]
    X_train_no_scale = X_train[no_scale_cols]
    X_test_scale = X_test[scale_cols]
    X_test_no_scale = X_test[no_scale_cols]

    X_train_scale = pd.DataFrame(scaler.fit_transform(X_train_scale),
                                 columns=X_train_scale.columns,
                                 index=X_train_scale.index)
    X_test_scale = pd.DataFrame(scaler.transform(X_test_scale),
                                columns=X_test_scale.columns,
                                index=X_test_scale.index)

    X_train = pd.concat([X_train_scale, X_train_no_scale], axis=1)
    X_test = pd.concat([X_test_scale, X_test_no_scale], axis=1)
    
    rf_reg = RandomForestRegressor(n_jobs=-1, random_state=42)
    grid_model = GridSearchCV(rf_reg, param_grid=grid,
                             cv=None, refit=True,
                             return_train_score=True)
    # fit
    grid_model.fit(X_train, y_train)
    # Predict
    train_pred = grid_model.predict(X_train)
    train_mae = mean_absolute_error(y_train, train_pred)
    train_mae_lst.append(train_mae)
    
    test_pred = grid_model.predict(X_test)
    test_mae = mean_absolute_error(y_test, test_pred)
    test_mae_lst.append(test_mae)
    # get best-parameter
    best_params = grid_model.best_params_
    param_lst.append(best_params)

# %%
print(param_lst)
print(train_mae_lst)
print(test_mae_lst)
# Out:
# [{'min_samples_split': 2, 'n_estimators': 100}, {'min_samples_split': 2, 'n_estimators': 100}, {'min_samples_split': 2, 'n_estimators': 300}, {'min_samples_split': 2, 'n_estimators': 300}, {'min_samples_split': 2, 'n_estimators': 100}]
# [71335.19496230295, 71452.8154568296, 70552.74612532358, 70680.15975483478, 71762.25475559615]
# [25829.969999999972, 79126.0, 138166.66666666663, 80351.96666666667, 305208.0]

# %% [markdown]
# - ``min_samples_split``은 ``2``로 공통적으로 최적의 파라미터임

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error

final_dataset['target'] = np.append(np.array(dataset['일매출'][1:]), 0) # make target variable
train_size = final_dataset.shape[0] - 5
tscv = TimeSeriesSplit(max_train_size=train_size,
                      test_size=1, n_splits=5)

grid = {'n_estimators': [50, 100, 300]} # overfitting 방지

cv_count = [c for c in range(1, 366)]
param_lst = []
train_mae_lst = []
test_mae_lst = []

for train_idx, test_idx in tscv.split(final_dataset.iloc[:-1]):
    train = final_dataset.iloc[train_idx]
    test = final_dataset.iloc[test_idx]
    
    X_train, y_train = train.iloc[:, :-1], train.iloc[:, -1]
    X_test, y_test = test.iloc[:, :-1], test.iloc[:, -1]
    
    scaler = MinMaxScaler()
    no_scale_cols = ['요일', '설_추석_가중치', '일반공휴일가중치']
    scale_cols = ['일매출', '한우가격', '육우가격', '돼지탕박가격', '평균상대습도', '최고기온', '평균풍속', '최대풍속',
                  '일사량', '일강수량']

    X_train_scale = X_train[scale_cols]
    X_train_no_scale = X_train[no_scale_cols]
    X_test_scale = X_test[scale_cols]
    X_test_no_scale = X_test[no_scale_cols]

    X_train_scale = pd.DataFrame(scaler.fit_transform(X_train_scale),
                                 columns=X_train_scale.columns,
                                 index=X_train_scale.index)
    X_test_scale = pd.DataFrame(scaler.transform(X_test_scale),
                                columns=X_test_scale.columns,
                                index=X_test_scale.index)

    X_train = pd.concat([X_train_scale, X_train_no_scale], axis=1)
    X_test = pd.concat([X_test_scale, X_test_no_scale], axis=1)
    
    rf_reg = RandomForestRegressor(n_jobs=-1, random_state=42, min_samples_split=2)
    grid_model = GridSearchCV(rf_reg, param_grid=grid,
                             cv=None, refit=True,
                             return_train_score=True)
    # fit
    grid_model.fit(X_train, y_train)
    # Predict
    train_pred = grid_model.predict(X_train)
    train_mae = mean_absolute_error(y_train, train_pred)
    train_mae_lst.append(train_mae)
    
    test_pred = grid_model.predict(X_test)
    test_mae = mean_absolute_error(y_test, test_pred)
    test_mae_lst.append(test_mae)
    # get best-parameter
    best_params = grid_model.best_params_
    param_lst.append(best_params)

# %%
print(param_lst)
print("Train MAE:", sum(train_mae_lst)/len(train_mae_lst))
print("Test MAE:", sum(test_mae_lst)/len(test_mae_lst))
# Out:
# [{'n_estimators': 100}, {'n_estimators': 100}, {'n_estimators': 300}, {'n_estimators': 300}, {'n_estimators': 100}]
# Train MAE: 71156.63421097741
# Test MAE: 125736.52066666665

# %% [markdown]
# - ``n_estimators`` 수를 많이 늘려보고 성능차이를 확인해보자.

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error

final_dataset['target'] = np.append(np.array(dataset['일매출'][1:]), 0) # make target variable
train_size = final_dataset.shape[0] - 5
tscv = TimeSeriesSplit(max_train_size=train_size,
                      test_size=1, n_splits=5)

grid = {'n_estimators': [100, 300, 500]} # overfitting 방지

cv_count = [c for c in range(1, 366)]
param_lst = []
train_mae_lst = []
test_mae_lst = []

for train_idx, test_idx in tscv.split(final_dataset.iloc[:-1]):
    train = final_dataset.iloc[train_idx]
    test = final_dataset.iloc[test_idx]
    
    X_train, y_train = train.iloc[:, :-1], train.iloc[:, -1]
    X_test, y_test = test.iloc[:, :-1], test.iloc[:, -1]
    
    scaler = MinMaxScaler()
    no_scale_cols = ['요일', '설_추석_가중치', '일반공휴일가중치']
    scale_cols = ['일매출', '한우가격', '육우가격', '돼지탕박가격', '평균상대습도', '최고기온', '평균풍속', '최대풍속',
                  '일사량', '일강수량']

    X_train_scale = X_train[scale_cols]
    X_train_no_scale = X_train[no_scale_cols]
    X_test_scale = X_test[scale_cols]
    X_test_no_scale = X_test[no_scale_cols]

    X_train_scale = pd.DataFrame(scaler.fit_transform(X_train_scale),
                                 columns=X_train_scale.columns,
                                 index=X_train_scale.index)
    X_test_scale = pd.DataFrame(scaler.transform(X_test_scale),
                                columns=X_test_scale.columns,
                                index=X_test_scale.index)

    X_train = pd.concat([X_train_scale, X_train_no_scale], axis=1)
    X_test = pd.concat([X_test_scale, X_test_no_scale], axis=1)
    
    rf_reg = RandomForestRegressor(n_jobs=-1, random_state=42, min_samples_split=2)
    grid_model = GridSearchCV(rf_reg, param_grid=grid,
                             cv=None, refit=True,
                             return_train_score=True)
    # fit
    grid_model.fit(X_train, y_train)
    # Predict
    train_pred = grid_model.predict(X_train)
    train_mae = mean_absolute_error(y_train, train_pred)
    train_mae_lst.append(train_mae)
    
    test_pred = grid_model.predict(X_test)
    test_mae = mean_absolute_error(y_test, test_pred)
    test_mae_lst.append(test_mae)
    # get best-parameter
    best_params = grid_model.best_params_
    param_lst.append(best_params)

# %%
print(param_lst)
print("Train MAE:", sum(train_mae_lst)/len(train_mae_lst))
print("Test MAE:", sum(test_mae_lst)/len(test_mae_lst))
# Out:
# [{'n_estimators': 100}, {'n_estimators': 100}, {'n_estimators': 500}, {'n_estimators': 300}, {'n_estimators': 100}]
# Train MAE: 71079.6866542544
# Test MAE: 124341.06733333334

# %% [markdown]
# - ``n_estimators``가 많아져도 성능에 차이가 없다.
# - 따라서 ``n_estimators = 100``으로 설정!

# %% [markdown]
# ## 최종 모델 RandomForest Regressor로 2020년 매출 예측

# %%
from sklearn.ensemble import RandomForestRegressor

rf_reg = RandomForestRegressor(n_estimators=100, min_samples_split=2, random_state=42)

test_df, train_cv_mae = evaluate_cv_predict(dataframe=final_dataset, regressor=rf_reg)
# Out:
# ## 10번째 교차검증 수행
# ## 20번째 교차검증 수행
# ## 30번째 교차검증 수행
# ## 40번째 교차검증 수행
# ## 50번째 교차검증 수행
# ## 60번째 교차검증 수행
# ## 70번째 교차검증 수행
# ## 80번째 교차검증 수행
# ## 90번째 교차검증 수행
# ## 100번째 교차검증 수행
# ## 110번째 교차검증 수행
# ## 120번째 교차검증 수행
# ## 130번째 교차검증 수행
# ## 140번째 교차검증 수행
# ## 150번째 교차검증 수행
# ## 160번째 교차검증 수행
# ## 170번째 교차검증 수행
# ## 180번째 교차검증 수행
# ## 190번째 교차검증 수행
# ## 200번째 교차검증 수행
# ## 210번째 교차검증 수행
# ## 220번째 교차검증 수행
# ## 230번째 교차검증 수행
# ## 240번째 교차검증 수행
# ## 250번째 교차검증 수행
# ## 260번째 교차검증 수행
# ## 270번째 교차검증 수행
# ## 280번째 교차검증 수행
# ## 290번째 교차검증 수행
# ## 300번째 교차검증 수행
# ## 310번째 교차검증 수행
# ## 320번째 교차검증 수행
# ## 330번째 교차검증 수행
# ## 340번째 교차검증 수행
# ## 350번째 교차검증 수행
# ## 360번째 교차검증 수행
# ## 365번 교차검증 수행 시간: 903.8714871406555
#
# ## 365번 교차검증에 대한 Train 데이터 MAE: 7만원
#
# ## 365번 교차검증에 대한 Test 데이터 MAE: 19만원
#
# ## 365번 교차검증 후 365번의 예측에 대해서 오차 10만원 미만으로 예측한 데이터 비율: 40.82%

# %% [markdown]
# ### 최종 모델 잔차 검정

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from sklearn.inspection import permutation_importance
import math

final_dataset['target'] = np.append(np.array(dataset['일매출'][1:]), 0) # make target variable

splits = math.floor(final_dataset.shape[0] * 0.9)
train = final_dataset.iloc[:splits]
test = final_dataset.iloc[splits:]

X_train, y_train = train.iloc[:, :-1], train.iloc[:, -1]
X_test, y_test = test.iloc[:, :-1], test.iloc[:, -1]

scaler = MinMaxScaler()
no_scale_cols = ['요일', '설_추석_가중치', '일반공휴일가중치']
scale_cols = ['일매출', '한우가격', '육우가격', '돼지탕박가격', '평균상대습도', '최고기온', '평균풍속', '최대풍속',
              '일사량', '일강수량']

X_train_scale = X_train[scale_cols]
X_train_no_scale = X_train[no_scale_cols]
X_test_scale = X_test[scale_cols]
X_test_no_scale = X_test[no_scale_cols]

X_train_scale = pd.DataFrame(scaler.fit_transform(X_train_scale),
                             columns=X_train_scale.columns,
                             index=X_train_scale.index)
X_test_scale = pd.DataFrame(scaler.transform(X_test_scale),
                            columns=X_test_scale.columns,
                            index=X_test_scale.index)

X_train = pd.concat([X_train_scale, X_train_no_scale], axis=1)
X_test = pd.concat([X_test_scale, X_test_no_scale], axis=1)

# fitting
rf_reg = RandomForestRegressor(n_jobs=-1, random_state=42, min_samples_split=2)
rf_reg.fit(X_train, y_train)

# Predict
train_pred = rf_reg.predict(X_train)
test_pred = rf_reg.predict(X_test)

# %% [markdown]
# #### 잔차 정규성

# %%
# 잔차 검정은 모델이 잘 만들어졌는지를 검정하기 위한 것임. 따라서 Train 잔차를 봐야 함!
train_resid = y_train - train_pred

plt.figure(figsize=(10, 4))
sns.distplot(train_resid)
plt.title("최종 모델 Random Forest의 잔차 히스토그램", fontsize=15)
plt.xlabel("Residual", fontsize=12)
plt.ylabel("KDE", fontsize=12)
plt.show()
# Out:
# /Users/younghun/opt/anaconda3/envs/venvforpython/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# QQ-plot for 잔차 정규성
import scipy.stats as stats

stats.probplot(train_resid, plot=plt)
plt.title("QQ-plot", fontsize=15)
plt.show()

# %%
from scipy.stats import kstest

stats_val, p_val = kstest(train_resid, 'norm')

if p_val < 0.05:
    print("귀무가설을 기각! Train Residual은 정규분포가 아니다!")
else:
    print("귀무가설을 채택! Train Residual은 정규분포를 따른다!")
# Out:
# 귀무가설을 기각! Train Residual은 정규분포가 아니다!

# %% [markdown]
# - ``Shapiro-wilk test``는 표본이 2000개 미만일 때 주로 사용하는 정규성 검정 방법
#     * 귀무가설: 해당 데이터가 정규성을 따른다!
# - ``Kolmogorove-Smirnov test``는 표본이 2000개 이상일 때 주로 사용하는 정규성 검정
#     * 귀무가설: 해당 데이터가 정규성을 따른다!
# - ``Quantile-Quantile Plot(QQ-plot)``은 그래프로 정규성 검정

# %% [markdown]
# #### 잔차 선형성, 독립성, 등분산성

# %%
# x축은 Train에 대한 예측값, y축은 잔차로 하는 Scatter plot for 선형성, 등분산성, 독립성
sns.scatterplot(x=y_train, y=train_resid)
plt.xlabel("Train Prediction", fontsize=15)
plt.ylabel("Train Residual", fontsize=15)
plt.show()

# %%
# 잔차 독립성 통계적 검정
from statsmodels.stats.stattools import durbin_watson

stats_val = durbin_watson(train_resid)

if 0 < stats_val < 2:
    print("Train Residual은 양의 자기상관이 존재")
elif 2 <= stats_val < 4:
    print("Train Residual은 자기상관이 존재하지 않음")
elif 4 <= stats_val:
    print("Train Residual은 음의 자기상관이 존재")
# Out:
# Train Residual은 자기상관이 존재하지 않음

# %% [markdown]
# #### 잔차 자기상관성

# %%
# 잔차에 대한 ACF 함수를 살펴보고 잔차의 자기상관이 있는지 살펴보기
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 4))
plot_acf(train_resid)
plt.title("Train Residual 자기상관함수(ACF)", fontsize=17)
plt.xlabel("Lag", fontsize=13)
plt.ylabel("자기상관계수", fontsize=13)
plt.show()

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox

stat_val, p_val = acorr_ljungbox(train_resid, lags=1)

if p_val < 0.05:
    print("귀무가설 기각! 해당 Train Residual은 자기상관성이 존재!")
else:
    print("귀무가설 채택! 해당 Train Residual은 독립적이다!")
# Out:
# 귀무가설 기각! 해당 Train Residual은 자기상관성이 존재!
# /Users/younghun/opt/anaconda3/envs/venvforpython/lib/python3.7/site-packages/statsmodels/stats/diagnostic.py:559: FutureWarning: The value returned will change to a single DataFrame after 0.12 is released.  Set return_df to True to use to return a DataFrame now.  Set return_df to False to silence this warning.
#   warnings.warn(msg, FutureWarning)

# %%
res_df = acorr_ljungbox(train_resid, lags=5, return_df=True)

for i in range(1, len(res_df)+1):
    if res_df.loc[i, 'lb_pvalue'] < 0.05:
        print("귀무가설 기각! 해당 Train Residual은 자기상관성이 존재!")
    else:
        print("귀무가설 채택! 해당 Train Residual은 독립적이다!")
# Out:
# 귀무가설 기각! 해당 Train Residual은 자기상관성이 존재!
# 귀무가설 기각! 해당 Train Residual은 자기상관성이 존재!
# 귀무가설 기각! 해당 Train Residual은 자기상관성이 존재!
# 귀무가설 기각! 해당 Train Residual은 자기상관성이 존재!
# 귀무가설 기각! 해당 Train Residual은 자기상관성이 존재!

# %% [markdown]
# - 잔차 검정 통계적 검정 방법 추가하기!
#     - Ljung-Box(자기상관성)
#     - Dubin-watson(독립성)
#     - Shappiro(정규성)

# %% [markdown]
# ## Feature Importance

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from sklearn.inspection import permutation_importance
import math

final_dataset['target'] = np.append(np.array(dataset['일매출'][1:]), 0) # make target variable

splits = math.floor(final_dataset.shape[0] * 0.9)
train = final_dataset.iloc[:splits]
test = final_dataset.iloc[splits:]

X_train, y_train = train.iloc[:, :-1], train.iloc[:, -1]
X_test, y_test = test.iloc[:, :-1], test.iloc[:, -1]

scaler = MinMaxScaler()
no_scale_cols = ['요일', '설_추석_가중치', '일반공휴일가중치']
scale_cols = ['일매출', '한우가격', '육우가격', '돼지탕박가격', '평균상대습도', '최고기온', '평균풍속', '최대풍속',
              '일사량', '일강수량']

X_train_scale = X_train[scale_cols]
X_train_no_scale = X_train[no_scale_cols]
X_test_scale = X_test[scale_cols]
X_test_no_scale = X_test[no_scale_cols]

X_train_scale = pd.DataFrame(scaler.fit_transform(X_train_scale),
                             columns=X_train_scale.columns,
                             index=X_train_scale.index)
X_test_scale = pd.DataFrame(scaler.transform(X_test_scale),
                            columns=X_test_scale.columns,
                            index=X_test_scale.index)

X_train = pd.concat([X_train_scale, X_train_no_scale], axis=1)
X_test = pd.concat([X_test_scale, X_test_no_scale], axis=1)

# fitting
rf_reg = RandomForestRegressor(n_jobs=-1, random_state=42, min_samples_split=2)
rf_reg.fit(X_train, y_train)

result = permutation_importance(rf_reg, X_train, y_train, n_repeats=5, random_state=42)

# %% [markdown]
# ### Permutation Importance

# %%
permut_df = pd.DataFrame(data={'Feature_중요도': result.importances_mean,
                               '중요도_표준편차': result.importances_std},
                         index=X_train.columns)
permut_df = permut_df.sort_values(by='Feature_중요도',
                                 ascending=False)
permut_df
# Out:
#           Feature_중요도  중요도_표준편차
# 일매출          1.741932  0.034687
# 설_추석_가중치     0.404762  0.017814
# 요일           0.072022  0.001098
# 한우가격         0.018453  0.001190
# 최고기온         0.016081  0.001052
# 돼지탕박가격       0.014817  0.000453
# 일사량          0.013476  0.001322
# 평균상대습도       0.011079  0.000583
# 평균풍속         0.009570  0.001209
# 육우가격         0.009505  0.000438
# 최대풍속         0.007991  0.000942
# 일강수량         0.005292  0.000433
# 일반공휴일가중치     0.000139  0.000014

# %% [markdown]
# ### Feature Importance of Random Forest

# %%
rf_importance = pd.DataFrame(data=rf_reg.feature_importances_,
                             index=X_train.columns,
                             columns=['Feature_중요도_RF'])
rf_importance = rf_importance.sort_values(by='Feature_중요도_RF', ascending=False)
rf_importance
# Out:
#           Feature_중요도_RF
# 일매출             0.622296
# 설_추석_가중치        0.248062
# 요일              0.024360
# 최고기온            0.017824
# 한우가격            0.016545
# 일사량             0.013121
# 돼지탕박가격          0.012182
# 평균상대습도          0.011279
# 육우가격            0.010339
# 평균풍속            0.009405
# 최대풍속            0.008591
# 일강수량            0.005816
# 일반공휴일가중치        0.000179

# %%
# Seaborn 그래프로 두 Featur Selection 방법으로 추출된 중요도 비교
fig, axes = plt.subplots(figsize=(7, 7), ncols=1, nrows=2, dpi=100)
plt.tight_layout(pad=5)

sns.barplot(data=permut_df, x='Feature_중요도', y=permut_df.index, ax=axes[0])
sns.barplot(data=rf_importance, x='Feature_중요도_RF', y=rf_importance.index, ax=axes[1])

axes[0].set_title("Feature 중요도 by permutation importance", fontsize=18)
axes[1].set_title("Feature 중요도 by Random Forest", fontsize=18)
plt.show()

# %%
# Seaborn 그래프로 두 Featur Selection 방법으로 추출된 중요도 비교
fig, axes = plt.subplots(figsize=(7, 7), ncols=1, nrows=2, dpi=100)
plt.tight_layout(pad=5)

sns.barplot(data=permut_df.iloc[1:], x='Feature_중요도', y=permut_df.index[1:], ax=axes[0])
sns.barplot(data=rf_importance.iloc[1:], x='Feature_중요도_RF', y=rf_importance.index[1:], ax=axes[1])

axes[0].set_title("Feature 중요도 by permutation importance", fontsize=18)
axes[1].set_title("Feature 중요도 by Random Forest", fontsize=18)
plt.show()
