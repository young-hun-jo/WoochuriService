# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Load-datasets" data-toc-modified-id="Load-datasets-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load datasets</a></span></li><li><span><a href="#Data-preprocessing" data-toc-modified-id="Data-preprocessing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data preprocessing</a></span><ul class="toc-item"><li><span><a href="#'beef_df'-preprocessing" data-toc-modified-id="'beef_df'-preprocessing-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>'beef_df' preprocessing</a></span></li><li><span><a href="#'pork_df'-preprocessing" data-toc-modified-id="'pork_df'-preprocessing-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>'pork_df' preprocessing</a></span></li><li><span><a href="#'sales'-preprocessing" data-toc-modified-id="'sales'-preprocessing-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>'sales' preprocessing</a></span></li><li><span><a href="#Merge-datasets" data-toc-modified-id="Merge-datasets-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Merge datasets</a></span></li></ul></li><li><span><a href="#Check-missing-values" data-toc-modified-id="Check-missing-values-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Check missing values</a></span><ul class="toc-item"><li><span><a href="#결측치가-존재하는-변수별로-일일이-조회해서-어떤-대체값을-선정할지-고안" data-toc-modified-id="결측치가-존재하는-변수별로-일일이-조회해서-어떤-대체값을-선정할지-고안-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>결측치가 존재하는 변수별로 일일이 조회해서 어떤 대체값을 선정할지 고안</a></span><ul class="toc-item"><li><span><a href="#결측치가-매우-많은-1시간최다강수량,-일강수량-변수들-살펴보기" data-toc-modified-id="결측치가-매우-많은-1시간최다강수량,-일강수량-변수들-살펴보기-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>결측치가 매우 많은 1시간최다강수량, 일강수량 변수들 살펴보기</a></span></li><li><span><a href="#날씨-변수들끼리-상관관계-살펴보기" data-toc-modified-id="날씨-변수들끼리-상관관계-살펴보기-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>날씨 변수들끼리 상관관계 살펴보기</a></span></li><li><span><a href="#결측치-변수마다-KNN-imputation-적용해서-결측치-대체한-후-unique한-변수들로-데이터프레임-형성" data-toc-modified-id="결측치-변수마다-KNN-imputation-적용해서-결측치-대체한-후-unique한-변수들로-데이터프레임-형성-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>결측치 변수마다 KNN imputation 적용해서 결측치 대체한 후 unique한 변수들로 데이터프레임 형성</a></span></li><li><span><a href="#결측치-대체된-데이터-원본-데이터에-병합" data-toc-modified-id="결측치-대체된-데이터-원본-데이터에-병합-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>결측치 대체된 데이터 원본 데이터에 병합</a></span></li></ul></li></ul></li><li><span><a href="#공휴일-부근-날짜에-가중치-부여하기" data-toc-modified-id="공휴일-부근-날짜에-가중치-부여하기-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>공휴일 부근 날짜에 가중치 부여하기</a></span></li><li><span><a href="#결측치-대체한-데이터-&amp;-공휴일-파생변수-생성한-데이터-병합-후-최종-데이터셋" data-toc-modified-id="결측치-대체한-데이터-&amp;-공휴일-파생변수-생성한-데이터-병합-후-최종-데이터셋-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>결측치 대체한 데이터 &amp; 공휴일 파생변수 생성한 데이터 병합 후 최종 데이터셋</a></span></li><li><span><a href="#데이터-EDA" data-toc-modified-id="데이터-EDA-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>데이터 EDA</a></span><ul class="toc-item"><li><span><a href="#날씨-변수들-EDA" data-toc-modified-id="날씨-변수들-EDA-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>날씨 변수들 EDA</a></span></li><li><span><a href="#일매출-EDA" data-toc-modified-id="일매출-EDA-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>일매출 EDA</a></span><ul class="toc-item"><li><span><a href="#연도별로-매출이-어떻게-변하는지-탐색" data-toc-modified-id="연도별로-매출이-어떻게-변하는지-탐색-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>연도별로 매출이 어떻게 변하는지 탐색</a></span></li><li><span><a href="#월별로-매출이-어떻게-변하는지-탐색" data-toc-modified-id="월별로-매출이-어떻게-변하는지-탐색-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>월별로 매출이 어떻게 변하는지 탐색</a></span></li><li><span><a href="#요일별로-매출이-어떻게-변하는지-탐색" data-toc-modified-id="요일별로-매출이-어떻게-변하는지-탐색-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>요일별로 매출이 어떻게 변하는지 탐색</a></span></li><li><span><a href="#일자별로-매출이-어떻게-변하는지-확인" data-toc-modified-id="일자별로-매출이-어떻게-변하는지-확인-6.2.4"><span class="toc-item-num">6.2.4&nbsp;&nbsp;</span>일자별로 매출이 어떻게 변하는지 확인</a></span></li><li><span><a href="#월,-요일,-일-별로-Two-way-이원-분산-분석-실시" data-toc-modified-id="월,-요일,-일-별로-Two-way-이원-분산-분석-실시-6.2.5"><span class="toc-item-num">6.2.5&nbsp;&nbsp;</span>월, 요일, 일 별로 Two-way 이원 분산 분석 실시</a></span></li><li><span><a href="#설날과-추석-휴무,-특이-휴무로-인해-발생한-매출액-0원에-대한-조치" data-toc-modified-id="설날과-추석-휴무,-특이-휴무로-인해-발생한-매출액-0원에-대한-조치-6.2.6"><span class="toc-item-num">6.2.6&nbsp;&nbsp;</span>설날과 추석 휴무, 특이 휴무로 인해 발생한 매출액 0원에 대한 조치</a></span></li></ul></li><li><span><a href="#한우,-육우,-돼지탕박-가격-EDA" data-toc-modified-id="한우,-육우,-돼지탕박-가격-EDA-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>한우, 육우, 돼지탕박 가격 EDA</a></span><ul class="toc-item"><li><span><a href="#가격의-이상치-확인" data-toc-modified-id="가격의-이상치-확인-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>가격의 이상치 확인</a></span></li><li><span><a href="#가격의-전체-시간의흐름/연도/월/요일/일자별에-따른-추세-파악" data-toc-modified-id="가격의-전체-시간의흐름/연도/월/요일/일자별에-따른-추세-파악-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>가격의 전체 시간의흐름/연도/월/요일/일자별에 따른 추세 파악</a></span><ul class="toc-item"><li><span><a href="#전체-시간의-흐름(2013-01-07~2020.12.31)" data-toc-modified-id="전체-시간의-흐름(2013-01-07~2020.12.31)-6.3.2.1"><span class="toc-item-num">6.3.2.1&nbsp;&nbsp;</span>전체 시간의 흐름(2013-01-07~2020.12.31)</a></span></li><li><span><a href="#각-가격의-연도/월/일자별-추세" data-toc-modified-id="각-가격의-연도/월/일자별-추세-6.3.2.2"><span class="toc-item-num">6.3.2.2&nbsp;&nbsp;</span>각 가격의 연도/월/일자별 추세</a></span></li></ul></li><li><span><a href="#가격들-간에-상관관계-확인" data-toc-modified-id="가격들-간에-상관관계-확인-6.3.3"><span class="toc-item-num">6.3.3&nbsp;&nbsp;</span>가격들 간에 상관관계 확인</a></span></li></ul></li></ul></li><li><span><a href="#시계열-데이터-통계적-검정" data-toc-modified-id="시계열-데이터-통계적-검정-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>시계열 데이터 통계적 검정</a></span></li></ul></div>

# %% [markdown]
# # Load datasets

# %%
import pandas as pd
import numpy as np
import os
os.chdir('/Users/younghun/Desktop/gitrepo/data/woochuri/')

# %%
len(pd.date_range(start='2009-01-01', end='2021-03-28'))
# Out:
# 4470

# %%
# 우추리 일별 매출 데이터
sales = pd.read_excel('./woochuri_sales.xlsx')
sales['datetime'] = pd.Series(pd.date_range(start='2013-01-07',
                                           end='2020-12-31',
                                           freq='D'))
cols = ['datetime', 'sales', 'remark']
sales = sales[cols]
sales = sales.rename(columns={'datetime':'날짜', 'sales':'일매출'})

# 일별 날씨 데이터 
weather = pd.read_csv('past_weather.csv', index_col=[0])
weather['시간'] = pd.to_datetime(weather['시간'])

# %%
# 소, 돼지 지역별 가격 데이터 각각 로드
import pymysql
db = pymysql.connect(host='localhost', user='root',
                    password='watson1259@', db='beef_pork_db',
                    charset='utf8')
cursor = db.cursor()

beef_sql = "SELECT DISTINCT * FROM beef_prices ORDER BY 날짜"
pork_sql = "SELECT DISTINCT * FROM pork_prices ORDER BY 날짜"

beef_df = pd.read_sql(beef_sql, db)
pork_df = pd.read_sql(pork_sql, db)

beef_df.shape, pork_df.shape
# Out:
# ((7365, 5), (8661, 5))

# %% [markdown]
# - 지역별 가격 중 한우, 육우별로 수도권/중부권/전국 지역 중 어떤 것을 선택할지 도메인 지식 전문가에게 물어보기

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## 'beef_df' preprocessing
# - 소 지역별 가격 데이터
# - 요일별로 나누어야 함
# - 주의해야 할 점
#     * 주말(토, 일)같은 경우는 빠져 있음
#         * 그러므로 금요일 가격으로 대체하는 것이 좋을듯!
#     * 지역값이 칼럼으로 가도록 Pivot 시키기

# %%
import pymysql
import pandas as pd
db = pymysql.connect(host='localhost', user='root',
                    password='watson1259@', db='beef_pork_db',
                    charset='utf8')
cursor = db.cursor()
# 소 데이터에서 2011년 3월 3일부터 '중부권'이 등장
beef_sql = "SELECT DISTINCT * FROM beef_prices WHERE 날짜 < '2011-03-03' AND 지역 = '전국'\
            UNION\
            SELECT DISTINCT * FROM beef_prices WHERE 날짜 >= '2011-03-03' AND 지역 = '중부권'\
            ORDER BY 날짜"
pork_sql = "SELECT DISTINCT * FROM pork_prices ORDER BY 날짜"

beef_df = pd.read_sql(beef_sql, db)
pork_df = pd.read_sql(pork_sql, db)

###### 소 변수 전처리 ######
hanwoo_df = beef_df[beef_df['종류'] == '한우']
yukwoo_df = beef_df[beef_df['종류'] == '육우']
# 현재 한우, 육우 둘다 중복된 row들 없음 -> 이제 중간 비어있는 값들은 주말(공휴일)로 이전의 값으로 대체!
hanwoo_df = hanwoo_df.rename(columns={'종류': '한우', '가격': '한우가격'})
yukwoo_df = yukwoo_df.rename(columns={'종류': '육우', '가격': '육우가격'})
 
raw_date_df = pd.DataFrame(pd.date_range(start='2009-01-01', end='2020-12-31', freq='D'))
raw_date_df = raw_date_df.rename(columns={0: '날짜'})
hanwoo_df = raw_date_df.merge(hanwoo_df, how='left')
hanwoo_df = hanwoo_df[['날짜', '한우가격']]
yukwoo_df = raw_date_df.merge(yukwoo_df, how='left')
yukwoo_df = yukwoo_df[['날짜', '육우가격']]
hanwoo_df = hanwoo_df.fillna(method='ffill')
yukwoo_df = yukwoo_df.fillna(method='ffill')
merge_beef_df = hanwoo_df.merge(yukwoo_df, how='inner', on='날짜')

###### 돼지 변수 전처리 ######
cond_tang = pork_df['종류'] == '탕박'
cond_n = pork_df['지역'] == '전국'
pork_df = pork_df[(cond_tang)&(cond_n)]

raw_date_df = pd.DataFrame(pd.date_range(start='2009-01-01', end='2020-12-31', freq='D'))
raw_date_df = raw_date_df.rename(columns={0: '날짜'})

merge_pork_df = raw_date_df.merge(pork_df, how='left')
merge_pork_df = merge_pork_df.fillna(method='ffill')
merge_pork_df = merge_pork_df.rename(columns={'가격': '돼지탕박가격'})
merge_cols = ['날짜', '돼지탕박가격']
merge_pork_df = merge_pork_df[merge_cols]

##### 소 & 돼지 변수 병합 #####
beef_pork_df = merge_beef_df.merge(merge_pork_df, how='inner', on='날짜')

# %% [markdown]
# ## 'pork_df' preprocessing

# %%
# 도메인 지식 상 시중에 판매되는 돼지고기 중 96.2%가 돼지 탕박임 -> 따라서 돼지 박피 데이터는 제거
# 또한 대전은 중부권이긴 하지만 지역의 종류에는 수도권, 영남권, 전국 밖에 없으므로 전국 값만 추출
cond_tang = pork_df['종류'] == '탕박'
cond_n = pork_df['지역'] == '전국'
pork_df = pork_df[(cond_tang)&(cond_n)]
pork_df = pork_df.drop_duplicates()

# %%
# 원래 범위의 날짜로 이루어진 데이터 프레임 만들고 이를 기준으로 left join 시키기
raw_date_df = pd.DataFrame(pd.date_range(start='2013-01-07', end='2020-12-31', freq='D'))
raw_date_df = raw_date_df.rename(columns={0: '날짜'})
merge_pork_df = raw_date_df.merge(pork_df, how='left', on='날짜')
merge_pork_df = merge_pork_df.fillna(method='ffill')
merge_pork_df = merge_pork_df.rename(columns={'가격': '돼지탕박가격'})

# %%
print('소 가격 데이터 shape:', merge_beef_df.shape)
print('돼지 가격 데이터 shape:', merge_pork_df.shape)
print(len(pd.date_range(start='2013-01-07', end='2020-12-31', freq='D')))
# Out:
# 소 가격 데이터 shape: (2916, 7)
# 돼지 가격 데이터 shape: (2916, 5)
# 2916

# %%
# 한우, 육우, 돼지탕박 일자별 가격 병합한 데이터셋 만들기
merge_df = merge_beef_df.merge(merge_pork_df, how='inner', on='날짜')
columns = ['날짜', '한우가격', '육우가격', '돼지탕박가격']
beef_pork_df = merge_df[columns]
print('한우&육우&돼지탕박 일자별 가격 데이터프레임 shape:', beef_pork_df.shape)
beef_pork_df.head()
# Out:
# 한우&육우&돼지탕박 일자별 가격 데이터프레임 shape: (2916, 4)
#           날짜     한우가격    육우가격  돼지탕박가격
# 0 2013-01-07  14548.0  9169.0  3140.0
# 1 2013-01-08  15082.0  8105.0  3024.0
# 2 2013-01-09  15030.0  9669.0  3096.0
# 3 2013-01-10  15229.0  9674.0  3000.0
# 4 2013-01-11  14920.0  8286.0  2963.0

# %% [markdown]
# ## 'sales' preprocessing

# %%
# remark의 결측치값은 모두 평일로 대체
sales['remark'] = sales['remark'].fillna('평일')

# %%
import holidays
from datetime import date
kor_holidays = holidays.Korea(years=[d for d in range(2013, 2021)])

holidays_dates = []
holidays_names = []
for date, name in kor_holidays.items():
    holidays_dates.append(date)
    holidays_names.append(name)
# 2013년 1월 7일부터이기 때문에 2013년 1월 7일 이전 공휴일은 설날 밖에없기 때문에 가장 첫 번째 요소 제거
holidays_df = pd.DataFrame({'공휴일날짜': holidays_dates,
                            '공휴일명': holidays_names}).sort_values(by='공휴일날짜')
holidays_df['공휴일날짜'] = pd.to_datetime(holidays_df['공휴일날짜'])

# sales(매출) 데이터로 날짜 기준으로 outer join 시키기
# 병합시킬 때 공휴일 데이터프레임 가장 첫 번째 행은 제외. 왜냐하면 2013년 1월 7일부터 데이터가 시작이기 때문!
sales_holiday_df = sales.merge(holidays_df.iloc[1:], how='outer', left_on='날짜', right_on='공휴일날짜')

# %% [markdown]
# ## Merge datasets
# - 우추리 매출 데이터
# - 일자별 공휴일 데이터
# - 일자별 날씨 데이터
# - 일자별 한우/육우(중부권), 돼지탕박(전국) 가격 데이터

# %%
sales_holiday_beef_pork = sales_holiday_df.merge(beef_pork_df, how='inner', on='날짜')
dataset = sales_holiday_beef_pork.merge(weather, how='inner', left_on='날짜', right_on='시간')

# %%
columns = dataset.columns.tolist()
columns.remove('시간')
dataset = dataset[columns]

# %% [markdown]
# ---

# %% [markdown]
# # Check missing values

# %%
dataset.isnull().sum()
# Out:
# 날짜             0
# 일매출            0
# remark         0
# 공휴일날짜       2780
# 공휴일명        2780
# 한우가격           0
# 육우가격           0
# 돼지탕박가격         0
# 지역             0
# 평균기온           0
# 최저기온           0
# 최고기온           0
# 1시간최다강수량    2202
# 일강수량        1733
# 평균풍속           2
# 최대풍속           0
# 평균상대습도         1
# 최소상대습도         0
# 1시간최다일사량       7
# 일사량            7
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')
plt.rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# 결측치가 존재하는 날씨 변수들 이상치 여부 확인하기
w_cols = dataset.columns[9:].tolist()
w_df = dataset[w_cols]

plt.figure(figsize=(13,5))
plt.title("날씨 변수 Box plot", fontsize=20)
sns.boxplot(data=w_df)
plt.show()

# %% [markdown]
# - 1시간최다강수량, 일강수량 변수를 제외한 변수들은 이상치 존재한다고 볼 수 없음
# <br><br>
# - 이상치 존재하는 1시간최다강수량, 일강수량 변수들은 결측치가 매우 많은 데이터임
# - 또한 1시간 최다강수량, 일강수량 같은 경우 여름철 장마같은 경우에는 강수량이 매우 많을 것이므로 이상치라고 판단할 수 없음

# %% [markdown]
# ## 결측치가 존재하는 변수별로 일일이 조회해서 어떤 대체값을 선정할지 고안

# %% [markdown]
# ### 결측치가 매우 많은 1시간최다강수량, 일강수량 변수들 살펴보기

# %%
cond = (dataset['1시간최다강수량'].isnull()) | (dataset['일강수량'].isnull())
miss_rain = dataset[cond]
miss_rain.head(50)
# Out:
#            날짜      일매출 remark      공휴일날짜  \
# 0  2013-01-07   422400     평일        NaT
# 1  2013-01-08   461900     평일        NaT
# 2  2013-01-09   492500     평일        NaT
# 3  2013-01-10   701300     평일        NaT
# 4  2013-01-11  1035000     평일        NaT
# 5  2013-01-12  1168600     평일        NaT
# 6  2013-01-13   696000     평일        NaT
# 7  2013-01-14   542000     평일        NaT
# 8  2013-01-15   503500     평일        NaT
# 9  2013-01-16   360500     평일        NaT
# 10 2013-01-17   369000     평일        NaT
# 11 2013-01-18   450300     평일        NaT
# 12 2013-01-19   906200     평일        NaT
# 13 2013-01-20   547700     평일        NaT
# 14 2013-01-21   330500     평일        NaT
# 15 2013-01-22   374900     평일        NaT
# 16 2013-01-23   402000     평일        NaT
# 17 2013-01-24   816400     평일        NaT
# 18 2013-01-25   482500     평일        NaT
# 19 2013-01-26   830500     평일        NaT
# 20 2013-01-27   619300     평일        NaT
# 21 2013-01-28   285500     평일        NaT
# ...

# %% [markdown]
# - 데이터를 살펴보니 1시간 최다강수량은 결측치가 매우 많기도 하며 일강수량 변수와 추후에 다중공선성이 있을 가능성이 매우 높기 때문에 **1시간최다강수량 변수는 삭제**

# %%
dataset = dataset.drop(['1시간최다강수량'], axis=1)

# %% [markdown]
# - 일강수량 결측치는 비가 오지 않은 즉 ``0.0``과 동일하기 때문에 모두 0으로 대체

# %%
dataset['일강수량'] = dataset['일강수량'].fillna(0.0)

# %% [markdown]
# ### 날씨 변수들끼리 상관관계 살펴보기

# %% [markdown]
# - 결측치가 존재하는 변수는 주로 날씨 변수들에 소속되어 있음. 그러므로 날씨 변수들끼리 상관관계를 확인해보자.

# %%
dataset.isnull().sum()
# Out:
# 날짜             0
# 일매출            0
# remark         0
# 공휴일날짜       2780
# 공휴일명        2780
# 한우가격           0
# 육우가격           0
# 돼지탕박가격         0
# 지역             0
# 평균기온           0
# 최저기온           0
# 최고기온           0
# 일강수량           0
# 평균풍속           2
# 최대풍속           0
# 평균상대습도         1
# 최소상대습도         0
# 1시간최다일사량       7
# 일사량            7
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')
plt.rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

weather_df = dataset[dataset.columns.tolist()[9:]]
corr_weather = weather_df.corr()
mask = np.triu(np.ones_like(corr_weather, dtype=bool))
plt.figure(figsize=(10, 8))
sns.heatmap(data=corr_weather, cmap='Blues', annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - 결측치가 존재하는 변수들(공휴일 변수 2개 제외) 각각 상관관계가 높은 변수들 정의
#     * 평균풍속(2개)
#         - 최대풍속(0.82)
#     * 평균상대습도(1개)
#         - 최소상대습도(0.92), 최저기온(0.44), 일강수량(0.41), 평균기온(0.34), 최고기온(0.23)
#     * 1시간최다일사량(7개)
#         - 최고기온(0.53), 평균기온(0.47), 최저기온(0.31), 최소상대습도(-0.5)
#     * 일사량(7개)
#         - 최고기온(0.57), 평균기온(0.47), 최저기온(0.35), 최소상대습도(-0.5)

# %% [markdown]
# ### 결측치 변수마다 KNN imputation 적용해서 결측치 대체한 후 unique한 변수들로 데이터프레임 형성

# %%
# 결측치 변수마다 각각 상관관계가 높은 변수들끼리 비지도 학습인 KNN을 수행하여 결측치 대체하기!
# 단, K값이 하이퍼파라미터이기 때문에 최적의 K값을 도출하지 못하는 한계는 존재..
# 우선 디폴트 K값이 5이기 때문에 5로 설정!
from sklearn.impute import KNNImputer

avg_wind = dataset[['평균풍속', '최대풍속']] # 결측치:평균풍속
avg_humid = dataset[['평균상대습도', '최소상대습도', '최저기온', '일강수량', '평균기온', '최고기온']] # 결측치:평균상대습도
max_sun_h = dataset[['1시간최다일사량', '최고기온', '평균기온', '최저기온', '최소상대습도']] # 결측치:1시가최다일사량
max_sun = dataset[['일사량', '최고기온', '평균기온', '최저기온', '최소상대습도']] # 결측치:일사량

knn_datasets = [avg_wind, avg_humid, max_sun_h, max_sun]
after_datasets = []
for data in knn_datasets:
    imputer = KNNImputer(n_neighbors=5, weights='uniform', metric='nan_euclidean')
    imputer.fit(data.values)
    after_values = imputer.transform(data.values) # array
    after_dataset = pd.DataFrame(after_values, columns=data.columns)
    after_datasets.append(after_dataset)
# 결측치 채운 데이터 프레임으로 전체 병합 후 distinct한 칼럼들만 추출해서 결측치가 채워진 날씨 변수들로 재탄생!
concat_df = pd.concat([after_datasets[0], after_datasets[1], after_datasets[2], after_datasets[3]], axis=1)

# dataframe boolean 인덱싱은 중복 제거되서 추출되지 않음.
#단, pd.DataFrame으로 데이터프레임을 만들 때 값과 칼럼이 동일한 것들은 자동으로 중복제거되어 만들어짐!
concat_cols = concat_df.columns.tolist()
transform_dict = {}
# 행벡터 -> 열벡터로 만들기 위해서 Transpose 사용
for i, v in enumerate(concat_df.values.T):
    transform_dict[concat_cols[i]] = v
    
transform_df = pd.DataFrame(transform_dict)

# %%
transform_df.head()
# Out:
#    평균풍속  최대풍속  평균상대습도  최소상대습도  최저기온  일강수량  평균기온  최고기온  1시간최다일사량    일사량
# 0   1.0   2.7    66.4    32.0 -10.7   0.0  -5.0   1.0      2.06  10.99
# 1   1.1   3.0    68.0    43.0  -9.2   0.0  -4.2   1.9      1.87  11.16
# 2   1.9   5.2    59.5    39.0  -9.7   0.0  -6.3  -1.9      2.13  12.34
# 3   1.1   3.1    54.9    29.0 -13.8   0.0  -7.9  -1.5      2.15  12.69
# 4   0.9   1.9    70.0    50.0 -12.8   0.0  -5.3   1.9      1.99  11.05

# %% [markdown]
# ### 결측치 대체된 데이터 원본 데이터에 병합
# - 매출(sales), 공휴일(holiday), 소,돼지 가격(beef, pork) 데이터 병합

# %%
standard_cols = set(dataset.columns) - set(transform_df.columns)
dataset = pd.concat([dataset[standard_cols], transform_df], axis=1)
print('결측치 대체 후 데이터 원본과 병합한 shape:', dataset.shape)
dataset.head()
# Out:
# 결측치 대체 후 데이터 원본과 병합한 shape: (2916, 19)
#       한우가격    육우가격  돼지탕박가격      일매출  지역 공휴일날짜         날짜 remark 공휴일명  평균풍속  \
# 0  14548.0  9169.0  3140.0   422400  대전   NaT 2013-01-07     평일  NaN   1.0
# 1  15082.0  8105.0  3024.0   461900  대전   NaT 2013-01-08     평일  NaN   1.1
# 2  15030.0  9669.0  3096.0   492500  대전   NaT 2013-01-09     평일  NaN   1.9
# 3  15229.0  9674.0  3000.0   701300  대전   NaT 2013-01-10     평일  NaN   1.1
# 4  14920.0  8286.0  2963.0  1035000  대전   NaT 2013-01-11     평일  NaN   0.9
#
#    최대풍속  평균상대습도  최소상대습도  최저기온  일강수량  평균기온  최고기온  1시간최다일사량    일사량
# 0   2.7    66.4    32.0 -10.7   0.0  -5.0   1.0      2.06  10.99
# 1   3.0    68.0    43.0  -9.2   0.0  -4.2   1.9      1.87  11.16
# 2   5.2    59.5    39.0  -9.7   0.0  -6.3  -1.9      2.13  12.34
# 3   3.1    54.9    29.0 -13.8   0.0  -7.9  -1.5      2.15  12.69
# 4   1.9    70.0    50.0 -12.8   0.0  -5.3   1.9      1.99  11.05

# %% [markdown]
# ---

# %% [markdown]
# # 공휴일 부근 날짜에 가중치 부여하기

# %%
pd.options.display.max_rows = 100
dataset.head()
# Out:
#       한우가격    육우가격  돼지탕박가격      일매출  지역 공휴일날짜         날짜 remark 공휴일명  평균풍속  \
# 0  14548.0  9169.0  3140.0   422400  대전   NaT 2013-01-07     평일  NaN   1.0
# 1  15082.0  8105.0  3024.0   461900  대전   NaT 2013-01-08     평일  NaN   1.1
# 2  15030.0  9669.0  3096.0   492500  대전   NaT 2013-01-09     평일  NaN   1.9
# 3  15229.0  9674.0  3000.0   701300  대전   NaT 2013-01-10     평일  NaN   1.1
# 4  14920.0  8286.0  2963.0  1035000  대전   NaT 2013-01-11     평일  NaN   0.9
#
#    최대풍속  평균상대습도  최소상대습도  최저기온  일강수량  평균기온  최고기온  1시간최다일사량    일사량
# 0   2.7    66.4    32.0 -10.7   0.0  -5.0   1.0      2.06  10.99
# 1   3.0    68.0    43.0  -9.2   0.0  -4.2   1.9      1.87  11.16
# 2   5.2    59.5    39.0  -9.7   0.0  -6.3  -1.9      2.13  12.34
# 3   3.1    54.9    29.0 -13.8   0.0  -7.9  -1.5      2.15  12.69
# 4   1.9    70.0    50.0 -12.8   0.0  -5.3   1.9      1.99  11.05

# %%
# 공휴일 관련 변수들만 추출
hol_cols = ['날짜', '일매출', 'remark', '공휴일날짜', '공휴일명']
holidays = dataset[hol_cols]

# %%
holidays['요일'] = holidays['날짜'].dt.day_name()
hol_cols = ['날짜', '요일','일매출', 'remark', '공휴일날짜', '공휴일명']
holidays = holidays[hol_cols]

# %% [markdown]
# - 우선 명절을 기준으로 몇일 전부터 매출이 많이 상승하는지 알아봐야 한다.
#     * 먼저 명절이 있는 날짜를 리스트에 담기
#     * 그리고 그 리스트의 날짜들 직전의 7일치까지의 데이터 Indexing을 리스트로 담기
#     * 해당 데이터들 출력해서 확인해보기

# %%
# 공휴일인 날짜들이 담겨있는 index 추출
from itertools import chain # for flattening 2d list

holidays_dates = holidays[~holidays['공휴일날짜'].isnull()]['날짜'].dt.strftime('%Y-%m-%d').values
holidays_arounds = []
for date in holidays_dates:
    around = pd.date_range(end=date, freq='D', periods=6)
    holidays_arounds.append(around)
holidays_arounds = list(chain.from_iterable(holidays_arounds))
holidays_arounds_df = holidays.loc[holidays['날짜'].isin(holidays_arounds)]

# %%
pd.options.display.max_rows = 500
holidays_arounds_df.head(500)
# Out:
#              날짜         요일       일매출 remark      공휴일날짜  \
# 28   2013-02-04     Monday   1332500     평일        NaT
# 29   2013-02-05    Tuesday   1390000     평일        NaT
# 30   2013-02-06  Wednesday   3145000     평일        NaT
# 31   2013-02-07   Thursday   5262500     평일        NaT
# 32   2013-02-08     Friday   7455480     평일        NaT
# 33   2013-02-09   Saturday   5430500     평일 2013-02-09
# 34   2013-02-10     Sunday         0    설휴무 2013-02-10
# 35   2013-02-11     Monday         0    설휴무 2013-02-11
# 48   2013-02-24     Sunday    400000     평일        NaT
# 49   2013-02-25     Monday    338000     평일        NaT
# 50   2013-02-26    Tuesday    478000     평일        NaT
# 51   2013-02-27  Wednesday    340000     평일        NaT
# 52   2013-02-28   Thursday    324000     평일        NaT
# 53   2013-03-01     Friday    420500     평일 2013-03-01
# 109  2013-04-26     Friday    510800     평일        NaT
# 110  2013-04-27   Saturday    836600     평일        NaT
# ...

# %% [markdown]
# - 우선 설날 당일 이전 날(The day preceding of Lunar New Year's Da) 또는 추석 당일 이전 날(The day preceding of Chuseok) 포함 직전까지 1,2,3,4,5,6으로 가중치 부여
# - 추석(Chuseok), 설날(Lunar) 키워드가 들어가지 않은 공휴일들은 공휴일 당일에 가중치 부여(공휴일이면 1 아니면 0)

# %%
lunar_chuseok = ["The day preceding of Lunar New Year's Day", "The day preceding of Chuseok"]
lunar_chuseok_dates = holidays[holidays['공휴일명'].isin(lunar_chuseok)]['날짜'].dt.strftime('%Y-%m-%d').values
lunar_chuseok_around_dates = []
for date in lunar_chuseok_dates:
    around = pd.date_range(end=date, freq='D', periods=6)
    lunar_chuseok_around_dates.append(around)
lunar_chuseok_arounds = list(chain.from_iterable(lunar_chuseok_around_dates))

# %%
lunar_chuseok_dict = {}
weight = 0
for around_date in lunar_chuseok_arounds:
    weight += 1
    if weight > 6:
        weight = 1
    lunar_chuseok_dict[around_date] = weight

# %%
# 추석, 설날 주변 날짜에 가중치 부여하는 함수 정의
def holidays_weights(df):
    df['설_추석_가중치'] = 0
    df['일반공휴일가중치'] = 0
    # 추석, 설날 주변 날짜에 가중치 부여
    if df['날짜'] in list(lunar_chuseok_dict.keys()):
        df['설_추석_가중치'] = lunar_chuseok_dict[df['날짜']]
    return df
# 추석, 설날 제외 일반 공휴일 당일에는 가중치 1 나머지 평일은 0을 부여한 파생변수 생성
holidays = holidays.apply(holidays_weights, axis=1)
holidays.loc[(~holidays['공휴일명'].str.contains('Lunar|Chuseok', na=False))&(holidays['공휴일명'].notnull()), '일반공휴일가중치'] = 1

# %%
# 필요한 변수들만 추출하기
need_cols = ['날짜', '요일', '일매출', '설_추석_가중치', '일반공휴일가중치']
holidays = holidays[need_cols]

# %%
holidays.head(500)
# Out:
#             날짜         요일      일매출  설_추석_가중치  일반공휴일가중치
# 0   2013-01-07     Monday   422400         0         0
# 1   2013-01-08    Tuesday   461900         0         0
# 2   2013-01-09  Wednesday   492500         0         0
# 3   2013-01-10   Thursday   701300         0         0
# 4   2013-01-11     Friday  1035000         0         0
# 5   2013-01-12   Saturday  1168600         0         0
# 6   2013-01-13     Sunday   696000         0         0
# 7   2013-01-14     Monday   542000         0         0
# 8   2013-01-15    Tuesday   503500         0         0
# 9   2013-01-16  Wednesday   360500         0         0
# 10  2013-01-17   Thursday   369000         0         0
# 11  2013-01-18     Friday   450300         0         0
# 12  2013-01-19   Saturday   906200         0         0
# 13  2013-01-20     Sunday   547700         0         0
# 14  2013-01-21     Monday   330500         0         0
# 15  2013-01-22    Tuesday   374900         0         0
# ...

# %% [markdown]
# ---

# %% [markdown]
# # 결측치 대체한 데이터 & 공휴일 파생변수 생성한 데이터 병합 후 최종 데이터셋

# %%
dataset_cols = ['한우가격', '육우가격', '돼지탕박가격', '평균상대습도', '최소상대습도', '평균기온',
               '최고기온', '최저기온', '평균풍속', '최대풍속', '일사량', '1시간최다일사량', '일강수량']
final_dataset = pd.concat([holidays, dataset[dataset_cols]], axis=1)

# %%
final_dataset.head()
# Out:
#           날짜         요일      일매출  설_추석_가중치  일반공휴일가중치     한우가격    육우가격  돼지탕박가격  \
# 0 2013-01-07     Monday   422400         0         0  14548.0  9169.0  3140.0
# 1 2013-01-08    Tuesday   461900         0         0  15082.0  8105.0  3024.0
# 2 2013-01-09  Wednesday   492500         0         0  15030.0  9669.0  3096.0
# 3 2013-01-10   Thursday   701300         0         0  15229.0  9674.0  3000.0
# 4 2013-01-11     Friday  1035000         0         0  14920.0  8286.0  2963.0
#
#    평균상대습도  최소상대습도  평균기온  최고기온  최저기온  평균풍속  최대풍속    일사량  1시간최다일사량  일강수량
# 0    66.4    32.0  -5.0   1.0 -10.7   1.0   2.7  10.99      2.06   0.0
# 1    68.0    43.0  -4.2   1.9  -9.2   1.1   3.0  11.16      1.87   0.0
# 2    59.5    39.0  -6.3  -1.9  -9.7   1.9   5.2  12.34      2.13   0.0
# 3    54.9    29.0  -7.9  -1.5 -13.8   1.1   3.1  12.69      2.15   0.0
# 4    70.0    50.0  -5.3   1.9 -12.8   0.9   1.9  11.05      1.99   0.0

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 EDA
# - EDA 살펴볼 변수들
#     * 날씨 변수들
#     * 일매출
#     * 한우, 육우, 돼지탕박 가격

# %% [markdown]
# ## 날씨 변수들 EDA

# %%
# box plot으로 날씨 변수들 살펴보기
w_cols = final_dataset.columns[8:].tolist()

plt.figure(figsize=(13, 5))
plt.title("날씨 변수들의 Box plot", fontsize=20)
sns.boxplot(data=final_dataset[w_cols])
plt.show()

# %%
final_dataset[w_cols].isnull().sum()
# Out:
# 평균상대습도      0
# 최소상대습도      0
# 평균기온        0
# 최고기온        0
# 최저기온        0
# 평균풍속        0
# 최대풍속        0
# 일사량         0
# 1시간최다일사량    0
# 일강수량        0
# dtype: int64

# %% [markdown]
# - 일 강수량은 이상치가 있는 것으로 판단
#     * 그러나 여름철 장마로 인한 값일 수 있으므로 일 강수량의 자세한 값 분포도를 살펴보자

# %%
rain_df = final_dataset[['날짜', '일강수량']]
# 날짜에 따른 일 강수량 분포 살펴보기
rain_df = rain_df.set_index('날짜')
rain_df['월'] = rain_df.index.month
rain_df['연도'] = rain_df.index.year


plt.figure(figsize=(13,5))
colors = ['r', 'b', 'g', 'y', 'orange', 'purple', 'k', 'm']
sns.lineplot(x='월', y='일강수량', hue='연도', data=rain_df, ci=None, palette=colors)
plt.title("연도별 월간 일강수량 분포도", fontsize=20)
plt.xlabel("Month", fontsize=15)
plt.ylabel("일강수량", fontsize=15)
plt.show()

# %% [markdown]
# - 일강수량의 이상치 값으로 간주되는 값들이 연도별로 6~8월(장마철)에 집중되어 있으므로 해당 값들을 이상치로 간주할 수 없음!

# %% [markdown]
# ## 일매출 EDA
#
# - 연도별로 매출이 어떻게 변하는지 살펴보기
#     * 매출이 계속 증가하는지(경기 악화라고 뉴스에선 나오지만 실질적으로 우추리 매장은 경기 호황?)
#     * 매출이 계속 감소하는지(계속적인 경기 악화?)
#     * 매출이 주기적으로 증가/감소하는지(매출의 증/감도 주기적인 싸이클을 갖는가?) -> 일종의 계절성이 존재하는가?
# <br><br>
# - 월별로 매출이 어떻게 변하는지 살펴보기
#     * 연초, 연말(1월, 12월)이 매출이 더 높은가?
#     * 봄/여름/가을/겨울 중 언제 매출이 가장 높은가?(단, 설날과 추석이 속해있는 월은 제거. 왜냐하면 설날, 추석이 있는 달에 매출이 상대적으로 평균값이 높아짐)
# <br><br>
# - 요일별로 매출이 어떻게 변하는지 살펴보기
#     * 금,토,일요일에는 상당히 매출이 높지 않을까?(단, 설,추석, 일반 공휴일 제외해야 함!)
#     * 월,화,수요일까지는 상대적으로 매출이 저조하지 않을까?
# <br><br>
# - 설, 추석 휴무, 특이휴무의 매출값은 어떻게 대체할 것인가?

# %%
# 위 EDA를 살펴보기 위해 필요한 변수들만 담은 데이터 추출
sale_cols = ['날짜', '일매출', 'remark', '공휴일날짜', '공휴일명']
sale_df = dataset[sale_cols]
sale_df.head()
# Out:
#           날짜      일매출 remark 공휴일날짜 공휴일명
# 0 2013-01-07   422400     평일   NaT  NaN
# 1 2013-01-08   461900     평일   NaT  NaN
# 2 2013-01-09   492500     평일   NaT  NaN
# 3 2013-01-10   701300     평일   NaT  NaN
# 4 2013-01-11  1035000     평일   NaT  NaN

# %%
# 우선 설,추석,특이 휴무 때는 매출이 0값이므로 이 데이터 개수 86개를 제외한 데이터들로 매출 추세 파악
print("매출값이 0인 데이터 개수:", sale_df[sale_df['일매출'] == 0].shape[0])
nonzero_sale_df = sale_df[sale_df['일매출'] != 0]
# Out:
# 매출값이 0인 데이터 개수: 86

# %% [markdown]
# ### 연도별로 매출이 어떻게 변하는지 탐색

# %%
# 연도별 칼럼 따로 생성
nonzero_sale_df['연도'] = nonzero_sale_df['날짜'].dt.year

# sns.lineplot 자체적으로 연도별 매출 평균값을 내어 매출 추세 확인
plt.figure(figsize=(13, 5))

sns.lineplot(x='연도', y='일매출', data=nonzero_sale_df, color='red')
plt.title("연도별 우추리 축산 평균 매출 추세", fontsize=20)
plt.xlabel("연도", fontsize=15)
plt.ylabel("평균매출", fontsize=15)
plt.show()

# %%
# 연도별로 그룹핑 후 매출 합계
yearly_sales = nonzero_sale_df.groupby('연도')['일매출'].sum()

# group_by로 연도별 매출 합계 계산 후 연도별 매출 합계 추세 그래프
plt.figure(figsize=(13, 5))
sns.lineplot(x='연도', y=yearly_sales.values, data=yearly_sales, color='red')
plt.title("연도별 우추리 축산 매출 합계 추세", fontsize=20)
plt.xlabel("연도", fontsize=15)
plt.ylabel("매출 합계", fontsize=15)
plt.show()

# %%
# 실질적으로 연도별 매출 합계가 얼마였는지 '만원' 단위로 나타내보기
import math

years = [y for y in range(yearly_sales.index[0], yearly_sales.index[-1]+1)]
for i, v in enumerate(yearly_sales.values):
    year = years[i]
    price = math.ceil(v/1e4)
    price_str = str(price)
    if i == 0:
        diff = 0
    else:
        diff = math.ceil((yearly_sales.values[i] - yearly_sales.values[i-1]) / 1e4)
    increase = '증가' if diff > 0 else '감소'
    print(f"# {year}년도 매출 합계: {price_str[0]}억 {price_str[1:]}만원\n# 이전 연도와의 매출 차이: {diff}만원 만큼 {increase}")
    print()
# Out:
# # 2013년도 매출 합계: 2억 3909만원
# # 이전 연도와의 매출 차이: 0만원 만큼 감소
#
# # 2014년도 매출 합계: 2억 8520만원
# # 이전 연도와의 매출 차이: 4612만원 만큼 증가
#
# # 2015년도 매출 합계: 2억 6372만원
# # 이전 연도와의 매출 차이: -2148만원 만큼 감소
#
# # 2016년도 매출 합계: 2억 8408만원
# # 이전 연도와의 매출 차이: 2037만원 만큼 증가
#
# # 2017년도 매출 합계: 2억 6953만원
# # 이전 연도와의 매출 차이: -1455만원 만큼 감소
#
# # 2018년도 매출 합계: 2억 4592만원
# # 이전 연도와의 매출 차이: -2360만원 만큼 감소
#
# # 2019년도 매출 합계: 2억 1183만원
# # 이전 연도와의 매출 차이: -3409만원 만큼 감소
#
# # 2020년도 매출 합계: 2억 3741만원
# # 이전 연도와의 매출 차이: 2559만원 만큼 증가

# %% [markdown]
# - 2013년도 부터 2016년도로의 변화는 증/감 추세 반복적으로 나타남
# - 하지만 **2016년도에서 2019년으로의 변화**는 **계속 감소** 추세
# - 마지막 2019년도 -> 2020년도는 매출이 증가했음. 하지만 증가한 매출이 2019년 이전인 2018년도의 매출만도 달성하지 못함.
# - (주관 견해) 따라서 2019년도까지 매출이 너무나도 떨어졌기 때문에 2020년도의 매출 향상은 일시적인 것으로 판단

# %% [markdown]
# ### 월별로 매출이 어떻게 변하는지 탐색

# %%
# 월(month) 칼럼 추가
nonzero_sale_df['월'] = nonzero_sale_df['날짜'].dt.month
nonzero_sale_df.head()
# Out:
#           날짜      일매출 remark 공휴일날짜 공휴일명    연도  월
# 0 2013-01-07   422400     평일   NaT  NaN  2013  1
# 1 2013-01-08   461900     평일   NaT  NaN  2013  1
# 2 2013-01-09   492500     평일   NaT  NaN  2013  1
# 3 2013-01-10   701300     평일   NaT  NaN  2013  1
# 4 2013-01-11  1035000     평일   NaT  NaN  2013  1

# %%
import matplotlib.pyplot as plt
# 전년도에 대해 월별 매출 합산 집계
monthly_sum = nonzero_sale_df.groupby('월')['일매출'].sum()

plt.figure(figsize=(10, 5))
sns.barplot(x=monthly_sum.index, y=monthly_sum.values)
plt.title("전 년도 월별 매출 합계 그래프", fontsize=20)
plt.xlabel("Month", fontsize=15)
plt.ylabel("매출액", fontsize=15)
plt.show()

# %% [markdown]
# - 9월은 추석 매출이 있기 때문에 매출이 매우 높은 것으로 예상
# - 또한 설날이 연도마다 1,2월에 번갈아서 존재하기 때문에 1,2월에 분리되어 높은 매출이 나타남
# - 나머지는 월별로 매출 합계가 매우 비슷
# <br><br>
# - 따라서 1,2,9월을 제외한 나머지 월 간에는 매출 합계가 매우 비슷함

# %% [markdown]
# - 그렇다면 추석, 설날인 매출들을 제외하고 월 별 매출을 비교해보자.
#     * 이 때, 월 별 매출 합계가 아닌 **매출 평균값**을 내야 한다. 왜냐하면 추석, 설날이 제외된 월은 그만큼 일(day)수도 줄기 때문이다.
# - 이를 통해서 추석, 설날 연휴인 날을 뺌으로써 월 별로 평시에 어떨 때 매출이 높은지 확인이 가능하다!

# %%
# 우선 매출액이 0인 설날,추석 때 쉰날 + 특이 휴무 때 쉰날의 데이터 제외해야 함
# 설날, 추석으로 인해 가중치가 더해진 데이터들만 제외만 하면 됨
# 설_추석_가중치가 포함된 final_dataset에서 추출해서 사용!

need_cols = ['날짜', '요일', '일매출', '설_추석_가중치', '일반공휴일가중치']
monthly_df = final_dataset[need_cols]
monthly_df['월'] = monthly_df['날짜'].dt.month

# %%
# 필요한 데이터들만 추출
print("설,추석,특이휴무&연휴로 인한 높은 매출 데이터 제외 전 shape:", monthly_df.shape)
monthly_df = monthly_df[(monthly_df['일매출'] != 0) & (monthly_df['설_추석_가중치'] == 0)]
print("설,추석,특이휴무&연휴로 인한 높은 매출 데이터 제외 후 shape:", monthly_df.shape)
# Out:
# 설,추석,특이휴무&연휴로 인한 높은 매출 데이터 제외 전 shape: (2916, 6)
# 설,추석,특이휴무&연휴로 인한 높은 매출 데이터 제외 후 shape: (2740, 6)

# %%
# 전처리 후 데이터 월별로 일매출 합계 그래프 그려보기
group_df = monthly_df.groupby('월')['일매출'].mean()

plt.figure(figsize=(10, 5))
sns.barplot(x=group_df.index, y=group_df.values)
plt.title("매출 특이 데이터 제외 후 월별 평균 일매출 그래프", fontsize=20)
plt.xlabel("Month", fontsize=15)
plt.ylabel("평균 매출", fontsize=15)
plt.show()

# %% [markdown]
# - 설, 추석 휴무가 평균적으로 대부분 존재하는 **1월, 9월**이 가장 매출이 높은 것으로 드러남
# - 이외에 봄/여름/가을/겨울 기준으로 보았을 때 **봄, 여름의 경우 매출이 상대적으로 저조**했고 **가을,겨울(2월제외)의 경우 매출이 상대적으로 높은**것으로 드러남

# %% [markdown]
# - 그렇다면 어린이날, 석가탄신일 같은 일반적인 공휴일 일때도 매출이 높은 경향이 있기 때문에 월 별로 일반 공휴일 개수를 세어보고 **일반 공휴일 개수와 매출값 사이의 피어슨 상관계수를 측정**해보자.

# %%
# 일반공휴일이라면 일반공휴일 가중치 값에 1을 부여했으므로 월별로 일반공휴일 가중치값의 sum을 구해보자
group_df = monthly_df.groupby('월').agg({'일매출': 'mean', '일반공휴일가중치': 'sum'})
group_df
# Out:
#               일매출  일반공휴일가중치
# 월
# 1   600913.095238         8
# 2   480294.915254         0
# 3   497279.183673         8
# 4   542193.697479         1
# 5   580892.469636        25
# 6   552294.237288         8
# 7   508488.120968         0
# 8   542734.465021         8
# 9   641428.729282         0
# 10  621225.847458        14
# 11  595824.893617         0
# 12  571577.336066         8

# %%
# 위 데이터프레임을 가지고 피어슨 상관계수 구하기
sns.heatmap(data=group_df.corr(), cmap='Blues', annot=True)
plt.title("일매출과 일반공휴일 개수 간의 피어슨 상관계수", fontsize=13, color='red')
plt.show()

# %% [markdown]
# - 상관계수 값은 ``0.2``로 약한 양의상관관계를 나타냄
# - 즉, **일반 공휴일 개수가 많을수록 매출의 소폭 증가를 야기**할 수 있음

# %% [markdown]
# ### 요일별로 매출이 어떻게 변하는지 탐색
#
# - 이에 대해서도 설, 추석, 특이 휴무인 매출액이 0인 데이터와 설,추석 가중치 데이터를 제외한 데이터셋으로 사용
#     * 왜냐하면 위 데이터들이 껴있으면 요일과 매출 간의 상관관계에 제 3의 변수가 개입하게 됨
# - 또한 주어진 기간(2013~2020년) 안에서 존재했던 요일별 횟수가 다르기 때문에 **매출의 평균값**을 사용
# - 기존 변수 ``monthly_df`` 변수 사용

# %%
# 요일 순으로 살펴보기 위해 요일별 카테고리값 순서 정의
weekday_cat = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']

group_df = monthly_df.groupby('요일')['일매출'].mean().reset_index()
group_df['요일'] = pd.Categorical(group_df['요일'], categories=weekday_cat, ordered=True)
group_df = group_df.sort_values(by='요일')

plt.figure(figsize=(10, 5))
sns.barplot(x='요일', y='일매출', data=group_df)
plt.title("매출 특이 데이터 제외 후 요일 평균 일매출 그래프", fontsize=20)
plt.xlabel("요일", fontsize=15)
plt.ylabel("평균 매출", fontsize=15)
plt.show()

# %% [markdown]
# - **토요일, 일요일**인 주말의 경우 평균매출이 가장 높음. 그중 **토요일**이 압도적으로 가장 높은 매출 기록
# - **금요일**은 다음날이 주말이기 때문에 매출이 높음
# - 요일 별 경향을 판단해보면, **주말이 끝나고 난 후 월요일부터 일주일의 중간인 수요일까지 매출이 하락을 보이다가 목요일부터 점차 매출이 상승**

# %% [markdown]
# ### 일자별로 매출이 어떻게 변하는지 확인
# - 요일별 때와 마찬가지로 일자별(1일~30/31일)로 매출 평균값 계산

# %%
monthly_df['일'] = monthly_df['날짜'].dt.day
group_df = monthly_df.groupby('일')['일매출'].mean().reset_index()
group_df = group_df.sort_values(by='일')

plt.figure(figsize=(10, 5))
sns.barplot(x='일', y='일매출', data=group_df)
plt.title("매출 특이 데이터 제외 후 일 평균 일매출 그래프", fontsize=20)
plt.xlabel("일(1일~31일)", fontsize=15)
plt.ylabel("평균 매출", fontsize=15)
plt.show()

# %% [markdown]
# - 1일~31일을 비교해보았을 때 **월 초(1,2,3일)와 월말(29,30,31)** 로 갈수록 매출이 높은 것을 볼 수 있다.
# - 반면에 그 외에 **나머지 일에는 매출이 매우 서로 비슷한 것**을 볼 수 있다.

# %% [markdown]
# ### 월, 요일, 일 별로 Two-way 이원 분산 분석 실시
# - 월, 요일, 일 별로 매출 평균값 차이가 있는 통계적 검정 실시

# %%
monthly_df.head()
# Out:
#           날짜         요일      일매출  설_추석_가중치  일반공휴일가중치  월   일
# 0 2013-01-07     Monday   422400         0         0  1   7
# 1 2013-01-08    Tuesday   461900         0         0  1   8
# 2 2013-01-09  Wednesday   492500         0         0  1   9
# 3 2013-01-10   Thursday   701300         0         0  1  10
# 4 2013-01-11     Friday  1035000         0         0  1  11

# %%
# 월 별 One-way ANOVA 분석
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

model = ols('일매출 ~ C(월)', monthly_df).fit()
res_df = anova_lm(model)
if res_df['PR(>F)'][0] < 0.05:
    print("월(Month) 별로 매출 평균값 차이가 있다. 즉, 통계적으로 유의하다.")
else:
    print("월(Month) 별로 매출 평균값이 동일하다. 즉, 통계적으로 유의하지 않다.")
res_df
# Out:
# 월(Month) 별로 매출 평균값 차이가 있다. 즉, 통계적으로 유의하다.
#               df        sum_sq       mean_sq         F   PR(>F)
# C(월)        11.0  5.785665e+12  5.259695e+11  2.906477  0.00081
# Residual  2728.0  4.936714e+14  1.809646e+11       NaN      NaN

# %%
# 요일 별 One-way ANOVA 분석
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

model = ols('일매출 ~ C(요일)', monthly_df).fit()
res_df = anova_lm(model)
if res_df['PR(>F)'][0] < 0.05:
    print("요일(Weekday) 별로 매출 평균값 차이가 있다. 즉, 통계적으로 유의하다.")
else:
    print("요일(Weekday) 별로 매출 평균값이 동일하다. 즉, 통계적으로 유의하지 않다.")
res_df
# Out:
# 요일(Weekday) 별로 매출 평균값 차이가 있다. 즉, 통계적으로 유의하다.
#               df        sum_sq       mean_sq         F        PR(>F)
# C(요일)        6.0  5.212788e+13  8.687981e+12  53.08004  3.963781e-62
# Residual  2733.0  4.473292e+14  1.636770e+11       NaN           NaN

# %%
# 일자 별 One-way ANOVA 분석
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

model = ols('일매출 ~ C(일)', monthly_df).fit()
res_df = anova_lm(model)
if res_df['PR(>F)'][0] < 0.05:
    print("일(Daily) 별로 매출 평균값 차이가 있다. 즉, 통계적으로 유의하다.")
else:
    print("일(Daily) 별로 매출 평균값이 동일하다. 즉, 통계적으로 유의하지 않다.")
res_df
# Out:
# 일(Daily) 별로 매출 평균값이 동일하다. 즉, 통계적으로 유의하지 않다.
#               df        sum_sq       mean_sq         F    PR(>F)
# C(일)        30.0  5.547602e+12  1.849201e+11  1.014252  0.444604
# Residual  2709.0  4.939095e+14  1.823217e+11       NaN       NaN

# %% [markdown]
# ### 설날과 추석 휴무, 특이 휴무로 인해 발생한 매출액 0원에 대한 조치

# %% [markdown]
# - 결측치 대체하는 방법
#     * 과감히 삭제 -> 특이 휴무는 언제 발생할지 모르는 값임
#     * 대푯값으로 대체 ->
#     * 특정한 Imputer 기술을 사용 ->
#
# - **이에 대한 결정 방법은 예측 모델링 단계에서 선정해야 할듯!** 현재 단계에서 우선 pass

# %% [markdown]
# ## 한우, 육우, 돼지탕박 가격 EDA
# - 각 가격의 이상치 여부 확인 -> boxplot으로
# - 각 가격이 전체(일자별로) 시간의 흐름에 따라 어떻게 변하는지 추세 파악
# - 각 가격이 연도/월/요일 별로 어떤 추세인지 파악
# - 현재 공휴일이나 일반 공휴일의 결측치는 데이터가 존재한 직전의 가격으로 대체한 상태임
#     * 따라서 공휴일 때 가격이 평일 가격보다 높은지 낮은지 파악할 수는 없음
# - 가격들의 서로 상관관계 확인(추후 모델링 단계 시 다중공선성 여부 파악 필요 결정)

# %%
# EDA 할 때 필요한 변수들만 추출
need_cols = ['날짜', '요일', '일매출', '한우가격', '육우가격', '돼지탕박가격']
price_df = final_dataset[need_cols]
print(price_df.columns)
# Out:
# Index(['날짜', '요일', '일매출', '한우가격', '육우가격', '돼지탕박가격'], dtype='object')

# %% [markdown]
# ### 가격의 이상치 확인

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=price_df[['한우가격', '육우가격', '돼지탕박가격']])
plt.title("소고기, 돼지 도매 가격의 분포도", fontsize=17)
plt.ylabel("가격", fontsize=14)
plt.show()

# %% [markdown]
# - 한우가격과 돼지탕박가격에는 이상치가 없는 것으로 보인다
# - 하지만 **육우가격**에는 매우 튀는 이상치가 존재
#     * 해당 이상치값이 무엇인지 알아보자

# %%
# Boxplot을 보고 육우가격이 1만5천원이 넘는 데이터들 조회
price_df[price_df['육우가격'] > 15000]
# Out:
#              날짜         요일     일매출     한우가격     육우가격  돼지탕박가격
# 2830 2020-10-07  Wednesday  205600  21186.0  22000.0  4579.0

# %% [markdown]
# - <a href='https://www.google.com/search?sxsrf=ALeKk009dmR6sl4WdtHkz2qI-cgf36NqYg:1615544667538&q=%EC%9C%A1%EC%9A%B0+%ED%95%9C%EC%9A%B0+%EA%B0%80%EA%B2%A9%EC%B0%A8%EC%9D%B4&sa=X&ved=2ahUKEwiY1ZvwxKrvAhXKb94KHT8zBAsQ1QIwEHoECA8QAQ&biw=1440&bih=798'>도메인 지식상</a>, 한우 가격은 육우가격의 약 1.8배에 달한다.
# - 그런데 위 데이터처럼 육우가격이 한우가격보다 높다는 것은 이상치일 것으로 판단.
# - 따라서 이상치 처리 로직 구현

# %%
print("전처리 전:", final_dataset.shape)
cond0 = final_dataset['한우가격'] < final_dataset['육우가격']
final_dataset.loc[cond0, '육우가격'] = final_dataset.loc[cond0]['한우가격'] * (10/18)
print("전처리 후:", final_dataset.shape)
# Out:
# 전처리 전: (2916, 18)
# 전처리 후: (2916, 18)

# %%
# price_df 재정의
need_cols = ['날짜', '요일', '일매출', '한우가격', '육우가격', '돼지탕박가격']
price_df = final_dataset[need_cols]

# %% [markdown]
# ### 가격의 전체 시간의흐름/연도/월/요일/일자별에 따른 추세 파악

# %%
# 연도, 월, 일 파생변수 생성
price_df['연도'] = price_df['날짜'].dt.year
price_df['월'] = price_df['날짜'].dt.month
price_df['일'] = price_df['날짜'].dt.day

# %% [markdown]
# #### 전체 시간의 흐름(2013-01-07~2020.12.31)

# %%
def plot_price(df, column):
    plot_df = df[['날짜', column]]
    
    plt.figure(figsize=(12, 5))
    plt.plot(plot_df['날짜'], plot_df[column])
    plt.title(f"{column} 동향 그래프", fontsize=20)
    plt.xlabel("2013-01-07 ~ 2020-12-31", fontsize=15)
    plt.ylabel(column, fontsize=15)
    plt.show()

cols = price_df.columns[3:6]
for col in cols:
    plot_price(price_df, col)

# %% [markdown]
# - 한우가격은 증가추세를 보이면서 계절성을 보임
# - 육우가격은 계절성을 보임
# - 돼지탕박가격은 계절성을 보임
#     <br><br>
# - 따라서 예측 모델링 시 확률적 모델링(ARIMA) 시 정상성을 확보할 필요가 있음(물론, 머신러닝을 활용한 모델링 시 정상성 확보가 필수는 아님!)

# %% [markdown]
# #### 각 가격의 연도/월/일자별 추세

# %%
group_df = price_df.groupby('연도')['한우가격'].mean().reset_index()
sns.lineplot(x='연도', y='한우가격', data=group_df)
# Out:
# <AxesSubplot:xlabel='연도', ylabel='한우가격'>

# %%
def plot_bar_graph(df, time_lst, price_lst):
    for time in time_lst:
        for price in price_lst:
            group_df = df.groupby(time)[price].mean().reset_index()
            
            plt.figure(figsize=(8, 4))
            sns.lineplot(x=time, y=price, data=group_df, color='red')
            plt.title(f"{time}별 {price} 그래프", fontsize=20)
            plt.xlabel(f"{time}", fontsize=15)
            plt.ylabel(f"평균 {price}", fontsize=15)
            plt.show()
        print('-'*80)

# %%
times = ['연도', '월', '일']
prices = ['한우가격', '육우가격', '돼지탕박가격']
plot_bar_graph(price_df, times, prices)
# Out:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------

# %% [markdown]
# ### 가격들 간에 상관관계 확인

# %%
corr = price_df[['일매출', '한우가격', '육우가격', '돼지탕박가격']].corr()

plt.figure(figsize=(8, 5))
sns.heatmap(data=corr, cmap='Blues', annot=True)
plt.show()

# %% [markdown]
# - **한우가격과 육우가격** 사이에 0.47의 양의 상관관계 존재 => 추후 모델링 시 VIF로 다중공선성 확인
# - **돼지탕박가격과 한우가격** 사이에 0.24의 양의 상관관계 존재 => VIF 확인해봐야겠지만 개인적으로 다중공선성은 없을 것으로 판단될 낮은 상관계수값

# %% [markdown]
# # 시계열 데이터 통계적 검정

# %% [markdown]
# - 시계열 데이터 예측 방법
#     * 고전적 방법
#         - 평활법
#             - 이동평균
#                 * 단순이동
#                 * 가중이동
#                 * 선형이동
#             - 지수평활
#                 * 계절모형
#     * 확률적 방법
#         - 시간영역
#             * ARIMA -> 정상성 확보되야 함!
#     * 머신러닝 방법

# %% [markdown]
# - 시계열 데이터 정상성 검정(ARIMA에만 해당)
#     * 그래프를 보고 판단
#         * 추세가 없는지 즉, 시계열의 평균이 시간 축에 평행한지
#         * 진폭(변동)이 일정한지. 즉, 분산이 일정한지
#         * 주기가 일정한지(=Covariance)
#         * ACF/PACF 그래프 관찰
#     * 검정통계량을 보고 판단
#         * KPSS 검정
#         * ADF(Augmented Dickey-Fuller) 검정
#             - 귀무가설 : 해당 시계열 데이터가 비정상성이다
#             - 대립가설 : 해당 시계열 데이터가 정상성이다
# <br><br>
# - 시계열 데이터 적합 후 잔차 검정 for 예측 모델의 robust 측정(모든 예측 방법에 해당)
#     * Ljung-Box Q 검정
#         - 귀무가설 : 잔차들의 자기상관성이 없음 즉,잔차들 간에 독립
#         - 대립가설 : 잔차들의 자기상관계수가 0이 아님. 즉, 잔차들 간에 상관관계 존재

# %% [markdown]
# <a href='https://machinelearningmastery.com/time-series-data-stationary-python/'>파이썬으로 시계열 정상성 체크방법</a>

# %%
final_dataset.to_csv('/Users/younghun/Desktop/gitrepo/data/woochuri/woochuri_final_data.csv',
                     index=False)
